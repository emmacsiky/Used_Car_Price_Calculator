# %%
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup as bts
import pandas as pd 
import re
import numpy as np
import time

# %%
def getAndParseURL(url):
    result=requests.get(url,headers={"User-Agent":"Chrome/109.0.5414.120"})
    soup=bts(result.text,"html.parser")
    return soup

# %%
pages=["https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50"]
for page in range(2,30):
    pages.append("https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=" +str (page))
    
pages
# Out:
# ['https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=2',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=3',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=4',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=5',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=6',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=7',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=8',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=9',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=10',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=11',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=12',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=13',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=14',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=15',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=16',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=17',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=18',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=19',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=20',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=21',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=22',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=23',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=24',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=25',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=26',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=27',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=28',
#  'https://www.arabam.com/ikinci-el/otomobil/mercedes-benz-c?take=50&page=29']

# %%
ex=getAndParseURL("https://www.arabam.com/ilan/galeriden-satilik-mercedes-benz-c-200-amg/mercedes-benz-certified-mengerler-2022-c200-coupe-4m-bjk-plaka/21874478")

# %%
ex.find("td",{"class":"listing-modelname pr"}).a.get("href")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 ex.find("td",{"class":"listing-modelname pr"}).a.get("href")
#
# AttributeError: 'NoneType' object has no attribute 'a'

# %%
cars=[]

for page in pages:
    html=getAndParseURL(page)
    for carlink in html.findAll("td",{"class":"listing-modelname pr"}):
        cars.append("https://www.arabam.com/"+carlink.a.get("href"))
        
cars
# Out:
# ['https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-4-classic/acil-opel-astra-1-4-classic-2007-model-van/21877882',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-6-cdti-sport/galeriden-opel-astra-1-6-cdti-sport-2014-model-mersin/21913943',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-edition/ilk-sahibinden-opel-astra-1-6-edition-2012-model/21908616',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-6-gls/1993-opel-astra-1-6/21904840',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-6-gls/galeriden-opel-astra-1-6-gls-1997-model-kocaeli/21903845',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-6-enjoy-plus/hatasiz-boyasiz-otomatik-opel-astra-1-6-enjoy-plus-2013-model/21894761',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-6-comfort/galeriden-opel-astra-1-6-comfort-2011-model-sanliurfa/21829260',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-3-cdti-edition/netkar-2012-opel-astra-hb-1-3cdti-95hp-edition-makyajli-kasa/21884503',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-3-cdti-enjoy-111-yil/galeriden-opel-astra-1-3-cdti-enjoy-111-yil-2011-model-mardin/21878134',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-6-cdti-sport/batuhan-dan-2015-opel-astra-1-6-cdti-136-hp-sport-stil-paket-sunroof-lu-hatasiz-boyasiz/21876297',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-edition-plus/sahibinden-opel-astra-1-6-edition-plus-2018-model/21872953',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-3-cdti-essentia-konfor/galeriden-opel-astra-1-3-cdti-essentia-konfor-2011-model-izmir/21874139',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-6-gl/203-bin-km-de-ok-gibi-opel-astra-1-6-gl-paket-klimali/21869351',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-3-cdti-enjoy/att-motorsdan-opel-astra-hasar-kayitsiz-otomatik-sunroof/21639127',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-4-essentia/galeriden-opel-astra-1-4-essentia-2005-model-malatya/21854274',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-4-t-cosmo/110-bin-km-tek-elden-binilmis-bi-arac/21851452',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-6-cdti-design/galeriden-opel-astra-1-6-cdti-design-2017-model-konya/21655972',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-3-cdti-enjoy/orjinal-176-000-km-de-asta-1-3-cdti-enjoy-cam-tavanli-otomatik/21758435',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-6-edition/aydin-otomotivden-hatasiz-2012-1-6-edition-opel-astra-benzin-lpg/20935152',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-4-t-sport/galeriden-opel-astra-1-4-t-sport-2013-model-hatay/21658092',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-6-cdti-business/galeriden-opel-astra-1-6-cdti-business-2015-model-osmaniye/21614716',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-4

#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-3-cdti-cosmo/hatasiz-boyasiz-2008-opel-astra-sedan-1-3-cdti-cosmo-sunroof-full/21858932',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-3-cdti-enjoy-plus/sahibinden-opel-astra-1-3-cdti-enjoy-plus-2012-model/21857136',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-gl/otomatik-orijinal-km-masrafsiz-temiz-opel-astra/19693756',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-elegance/memurdan-otomatik-ozel-plakali-opel-astra-1-6-elegance-2001-model/21655776',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-3-cdti-enjoy/temiz-aile-araci/21856424',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-enjoy/sahibinden-opel-astra-1-6-enjoy-2004-aile-araci/21855164',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-4-t-sport/sahibinden-opel-astra-1-4-t-sport-2013-model/21858445',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-essentia/sahibinden-opel-astra-1-6-essentia-2013-model/21856536',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-3-cdti-business/sahibinden-opel-astra-1-3-cdti-business-2014-model/21856131',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-edition-plus/sahibinden-opel-astra-1-6-edition-plus-2017-model/21855621',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-cd/sahibinden-opel-astra-1-6-cd-1999-model/21857026',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-3-cdti-cosmo/astra-air-full-full-degisensiz-boyasiz/21856043',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-4-t-enjoy/sahibinden-opel-astra-1-4-t-enjoy-2010-model/21855828',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-6-cdti-design/mila-otomotiv/21858479',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-edition-plus/sahibinden-opel-astra-1-6-edition-plus-2017-model/21856752',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-4-gl/sahibinden-opel-astra-1-4-gl-1997-model/21854645',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-essentia/sahibinden-opel-astra-1-6-essentia-2011-model/21857018',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-essentia-konfor/sahibinden-opel-astra-1-6-essentia-konfor-2012-model/21855273',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-edition-plus/sahibinden-opel-astra-1-6-edition-plus-2016-model/21853914',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-cdti-design/sahibinden-opel-astra-1-6-cdti-design-2017-model/21856019',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-cdti-sport/sahibinden-opel-astra-1-6-cdti-sport-2015-model/21855003',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-4-t-edition-plus/inoto-garaj-astra/21858223',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-4-t-cosmo/ogretmenden-opel-astra-1-4-t-cosmo-2012-model-eskisehir/21856432',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-4-gl/1998-astra-hidrolik-direksiyonlu-hasar-kayitsiz/21853901',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-classic/sahibinden-opel-astra-1-6-classic-tiwinport-2006-model/21855753',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-6-elegance/sahibinden-opel-astra-1-6-elegance-2004-model/21856869',
#  'https://www.arabam.com//ilan/galeriden-satilik-opel-astra-1-3-cdti-cosmo/setap-auto-opel-astra-1-3-cdti-cosmo-2013-model-sanliurfa/21858178',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-3-cdti-enjoy/sahibinden-opel-astra-1-3-cdti-enjoy-2008-model/21856528',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-2-turbo-edition/sahibinden-opel-astra-1-2-turbo-edition-2021-model/21854235',
#  'https://www.arabam.com//ilan/sahibinden-satilik-opel-astra-1-3-cdti-enjoy/sahibinden-opel-astra-1-3-cdti-enjoy-2009-model-130-000-km-mavi/21857256',
#  ...]

# %%
len(cars)
# Out:
# 2400

# %%
ex.find("ul",{"class":"w100 cf mt12 detail-menu"})
# Out:
# <ul class="w100 cf mt12 detail-menu">
# <li class="bcd-list-item">
# <span class="bli-particle bold">İlan No:</span>
# <span class="bli-particle semi-bold">
#                                             21874478
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">İlan Tarihi:</span>
# <span class="bli-particle">
#                                             27 Ocak 2023
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Marka:</span>
# <span class="bli-particle" title="Mercedes - Benz">
#                                             Mercedes - Benz
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Seri:</span>
# <span class="bli-particle">
#                                             C
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Model:</span>
# <span class="bli-particle">
#                                             C 200 AMG
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Yıl:</span>
# <span class="bli-particle">
#                                             2022
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Kilometre:</span>
# <span class="bli-particle">
#                                             24.051 km
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Vites Tipi:</span>
# <span class="bli-particle">
#                                             Otomatik
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Yakıt Tipi:</span>
# <span class="bli-particle">
#                                             Benzin
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Kasa Tipi:</span>
# <span class="bli-particle">
#                                             Coupe
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Motor Hacmi:</span>
# <span class="bli-particle">
#                                             1497 cc
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Motor Gücü:</span>
# <span class="bli-particle">
#                                             184 hp
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Çekiş:</span>
# <span class="bli-particle" title="4WD (Sürekli)">
#                                             4WD (Sürekli)
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Ort. Yakıt Tüketimi:</span>
# <span class="bli-particle">
#                                             7 lt
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Yakıt Deposu:</span>
# <span class="bli-particle">
#                                             50 lt
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Boya-değişen:</span>
# <a class="bli-particle semi-bold" ng-click="self.resolveTabById('js-hook-for-observer-boyadegisen')">1 boyalı</a>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Takasa Uygun:</span>
# <span class="bli-particle">
#                                             Takasa Uygun
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Kimden:</span>
# <span class="bli-particle">
#                                             Galeriden
#
#                                         </span>
# </li>
# </ul>

# %%
ex.find("span",{"class":"pl4 one-line-overflow"})

# %%
ex.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Yıl")).findNext().text.strip()
# Out:
# '2022'

# %%
ex.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Model")).findNext().text.strip()
# Out:
# 'C 200 AMG'

# %%
ex.find("div",{"class":"color-red4 font-default-plusmore bold fl"}).text.strip()
# Out:
# '2.305.900 TL'

# %%
features = []
for carl in cars:
    html=getAndParseURL(carl)
    try:
        brand =html.find("ul",{"w100 cf mt12 detail-menu"}).find(text=re.compile("Marka")).findNext().text.strip()
    except:
        brand = np.nan
    try:
        model=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Model")).findNext().text.strip()
    except:
        model=np.nan
    try:
        year=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Yıl")).findNext().text.strip()
    except:
        year=np.nan
    try:
        km=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Kilometre")).findNext().text.strip()
    except:
        km=np.nan
    try:
        engsize=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Motor Hacmi")).findNext().text.strip()
    except:
        engsize=np.nan
    try:
        hp=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Motor Gücü")).findNext().text.strip()
    except:
        hp=np.nan
    try:
        fuel=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Yakıt Tipi")).findNext().text.strip()
    except:
        fuel=np.nan
    try:
        gear=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Vites Tipi")).findNext().text.strip()
    except:
        gear=np.nan
    try:
        fuelcoms=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Yakıt Tüketimi")).findNext().text.strip()
    except:
        fuelcoms=np.nan
    try:
        price=html.find("div",{"class":"color-red4 font-default-plusmore bold fl"}).text.strip()
    except:
        price=np.nan
                    
    features.append([brand,model,year,km,engsize,hp,fuel,gear,fuelcoms,price])
    
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In [18], line 3
#       1 features = []
#       2 for carl in cars:
# ----> 3     html=getAndParseURL(carl)
#       4     try:
#       5         brand =html.find("ul",{"w100 cf mt12 detail-menu"}).find(text=re.compile("Marka")).findNext().text.strip()
#
# Cell In [8], line 2, in getAndParseURL(url)
#       1 def getAndParseURL(url):
# ----> 2     result=requests.get(url,headers={"User-Agent":"Chrome/109.0.5414.120"})
#       3     soup=bts(result.text,"html.parser")
#       4     return soup
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:547, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     544             raise
#     546 except (ProtocolError, OSError) as err:
# --> 547     raise ConnectionError(err, request=request)
#     549 except MaxRetryError as e:
#     550     if isinstance(e.reason, ConnectTimeoutError):
#     551         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
features
# Out:
# [['Toyota',
#   '1.6 Vision',
#   '2020',
#   '80.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '605.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2021',
#   '41.060 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '864.000 TL'],
#  ['Toyota',
#   '1.6 Sol',
#   '2005',
#   '157.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,5 lt',
#   '367.500 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2021',
#   '40.389 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '853.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Passion X-Pack',
#   '2019',
#   '123.282 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '848.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Flame X-Pack',
#   '2021',
#   '29.239 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '978.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2018',
#   '208.500 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '525.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2006',
#   '283.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '280.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2016',
#   '75.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Düz',
#   '6,3 lt',
#   '495.000 TL'],
#  ['Toyota',
#   '1.3 XL',
#   '1994',
#   '310.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '130.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2020',
#   '40.100 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '785.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2020',
#   '125.314 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '765.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '1999',
#   '271.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '242.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2016',
#   '160.000 km',
#   '1201 - 1400 cm3',
#   '76 - 100 HP',
#   'Dizel',
#   'Yarı Otomatik',
#   nan,
#   '475.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2017',
#   '155.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '568.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2022',
#   '6.200 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '915.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2004',
#   '300.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '205.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2012',
#   '104.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '444.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2007',
#   '365.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '225.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2011',
#   '209.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '340.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2013',
#   '197.150 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '428.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2016',
#   '127.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '510.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2016',
#   '137.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '527.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2015',
#   '56.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '392.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Premium',
#   '2015',
#   '94.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '655.000 TL'],
#  ['Toyota',
#   '1.6 Life',
#   '2018',
#   '51.011 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Düz',
#   '6,3 lt',
#   '580.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2021',
#   '47.405 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '863.000 TL'],
#  ['Toyota',
#   '1.33 Comfort',
#   '2011',
#   '134.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '365.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2006',
#   '175.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '292.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Active',
#   '2014',
#   '125.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '595.000 TL'],
#  ['Toyota',
#   '1.33 Comfort',
#   '2010',
#   '310.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '320.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2019',
#   '109.000 km',
#   '1798 cc',
#   '122 hp',
#   'LPG & Benzin',
#   'Yarı Otomatik',
#   nan,
#   '659.950 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2009',
#   '189.500 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,9 lt',
#   '412.000 TL'],
#  ['Toyota',
#   '1.6 Comfort',
#   '2009',
#   '191.000 km',
#   '1598 cc',
#   '124 hp',
#   'Benzin',
#   'Yarı Otomatik',
#   '6,7 lt',
#   '410.000 TL'],
#  ['Toyota',
#   '1.3 Terra',
#   '1999',
#   '254.000 km',
#   '1332 cc',
#   '86 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,9 lt',
#   '196.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2021',
#   '39.456 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '849.000 TL'],
#  ['Toyota',
#   '1.6 Elegant',
#   '2009',
#   '114.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,2 lt',
#   '454.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2011',
#   '148.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '452.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Active',
#   '2015',
#   '102.400 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '510.000 TL'],
#  ['Toyota',
#   '1.6 Sol',
#   '2007',
#   '163.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '366.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2020',
#   '30.500 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '700.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1996',
#   '316.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '185.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1996',
#   '303.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '223.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2014',
#   '136.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '545.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2013',
#   '124.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '498.750 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2015',
#   '82.500 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '549.750 TL'],
#  ['Toyota',
#   '1.6 GL',
#   '1993',
#   '272.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '180.000 TL'],
#  ['Toyota',
#   '1.6 Sol Special',
#   '2002',
#   '300.700 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7 lt',
#   '290.000 TL'],
#  ['Toyota',
#   '1.6 Comfort Extra',
#   '2011',
#   '56.600 km',
#   '1598 cc',
#   '124 hp',
#   'Benzin',
#   'Düz',
#   '7 lt',
#   '450.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Sol',
#   '2007',
#   '475.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '275.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Sol',
#   '2007',
#   '475.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '275.000 TL'],
#  ['Toyota',
#   '1.6 Sol',
#   '2005',
#   '232.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '348.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2021',
#   '17.000 km',
#   '1601 - 1800 cm3',
#   '101 - 125 HP',
#   'Hibrit',
#   'Otomatik',
#   nan,
#   '821.900 TL'],
#  ['Toyota',
#   '1.4 D-4D Class',
#   '2010',
#   '230.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '365.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2014',
#   '165.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '527.000 TL'],
#  ['Toyota',
#   '1.5 Dream',
#   '2022',
#   '6.900 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '776.500 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2020',
#   '29.000 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '815.000 TL'],
#  ['Toyota',
#   '1.6 Flame X Pack',
#   '2019',
#   '41.700 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '810.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1993',
#   '332.500 km',
#   '1401 - 1600 cm3',
#   '101 - 125 HP',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '188.500 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2005',
#   '182.500 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '320.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2020',
#   '27.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '725.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1998',
#   '395.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '213.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2008',
#   '240.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,9 lt',
#   '310.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2010',
#   '149.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '387.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2011',
#   '242.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '365.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2007',
#   '210.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '317.500 TL'],
#  ['Toyota',
#   '1.3 Terra',
#   '2000',
#   '332.000 km',
#   '1332 cc',
#   '86 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '200.000 TL'],
#  ['Toyota',
#   '1.4 Terra',
#   '2002',
#   '236.000 km',
#   '1398 cc',
#   '97 hp',
#   'Benzin',
#   'Düz',
#   '6,8 lt',
#   '199.500 TL'],
#  ['Toyota',
#   '1.3 XL',
#   '1994',
#   '295.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '137.500 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2007',
#   '198.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '325.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2006',
#   '191.250 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '370.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1991',
#   '350.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '128.000 TL'],
#  ['Toyota',
#   '1.3 XE',
#   '1995',
#   '223.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '175.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1997',
#   '235.000 km',
#   '1587 cc',
#   '114 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '190.000 TL'],
#  ['Toyota',
#   '1.6 Flame X Pack',
#   '2020',
#   '39.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '827.500 TL'],
#  ['Toyota',
#   '1.3 XL',
#   '1998',
#   '299.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '155.500 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2015',
#   '139.666 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '542.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Flame X-Pack',
#   '2020',
#   '70.896 km',
#   '1800 cc',
#   '122 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   nan,
#   '817.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2019',
#   '50.683 km',
#   '1800 cc',
#   '122 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   nan,
#   '742.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2019',
#   '121.737 km',
#   '1800 cc',
#   '122 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   nan,
#   '687.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2015',
#   '133.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '436.000 TL'],
#  ['Toyota',
#   '1.6 Comfort Extra',
#   '2010',
#   '351.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,1 lt',
#   '346.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2014',
#   '150.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '499.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2011',
#   '145.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '470.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1991',
#   '480.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '138.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1995',
#   '440.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '210.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1995',
#   '467.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '195.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1997',
#   '368.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '190.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2018',
#   '136.750 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '535.900 TL'],
#  ['Toyota',
#   '1.6 XLi',
#   '1996',
#   '294.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '185.000 TL'],
#  ['Toyota',
#   '1.6 Flame X Pack',
#   '2019',
#   '25.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '835.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1997',
#   '200.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '245.000 TL'],
#  ['Toyota',
#   '1.33 Comfort',
#   '2011',
#   '155.500 km',
#   '1329 cc',
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '300.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2019',
#   '83.479 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '739.950 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1997',
#   '340.546 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '214.750 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1996',
#   '386.546 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '197.500 TL'],
#  ['Toyota',
#   '1.6 Dream',
#   '2020',
#   '44.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '745.000 TL'],
#  ['Toyota',
#   '1.6 Dream',
#   '2020',
#   '24.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '767.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2017',
#   '137.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '539.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2009',
#   '199.500 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '333.000 TL'],
#  ['Toyota',
#   '1.5 Flame',
#   '2022',
#   '6.012 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '859.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1998',
#   '177.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '350.000 TL'],
#  ['Toyota',
#   '1.33 Comfort',
#   '2010',
#   '126.000 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '385.000 TL'],
#  ['Toyota',
#   '1.6 Elegant',
#   '2011',
#   '135.000 km',
#   '1598 cc',
#   '124 hp',
#   'Benzin',
#   'Düz',
#   '7 lt',
#   '385.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2012',
#   '257.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '370.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Class',
#   '2008',
#   '315.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '265.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2017',
#   '82.000 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '478.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2019',
#   '58.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '745.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2012',
#   '208.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '423.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2016',
#   '38.000 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '505.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1998',
#   '294.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '210.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1993',
#   '262.000 km',
#   '1587 cc',
#   '114 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '160.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2017',
#   '161.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '510.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2006',
#   '160.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '375.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2020',
#   '11.650 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '728.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2013',
#   '106.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '530.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2006',
#   '208.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '283.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2010',
#   '231.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '400.000 TL'],
#  ['Toyota',
#   '1.6 Flame X Pack',
#   '2020',
#   '65.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '730.000 TL'],
#  ['Toyota',
#   '1.6 GLi Special',
#   '1998',
#   '340.000 km',
#   '1587 cc',
#   '114 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '192.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Class',
#   '2009',
#   '326.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '285.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2017',
#   '63.158 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '603.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2009',
#   '359.500 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '236.000 TL'],
#  ['Toyota',
#   '1.6 Elegant',
#   '2010',
#   '90.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '419.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2015',
#   '94.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '597.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Life',
#   '2013',
#   '168.500 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '437.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2018',
#   '28.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '629.900 TL'],
#  ['Toyota',
#   '1.2 Turbo Flame',
#   '2020',
#   '9.900 km',
#   '1197 cc',
#   '116 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '810.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2021',
#   '40.253 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '864.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2006',
#   '190.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '289.900 TL'],
#  ['Toyota',
#   '1.6 Dream',
#   '2020',
#   '17.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '789.500 TL'],
#  ['Toyota',
#   '1.6 Comfort Extra',
#   '2012',
#   '160.000 km',
#   '1598 cc',
#   nan,
#   'Benzin',
#   'Düz',
#   '6,9 lt',
#   '430.000 TL'],
#  ['Toyota',
#   '1.6 Terra Special VVT-i',
#   '2005',
#   '225.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '330.000 TL'],
#  ['Toyota',
#   '1.5 Flame X-Pack',
#   '2021',
#   '29.000 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '819.750 TL'],
#  ['Toyota',
#   '1.6 Comfort',
#   '2010',
#   '70.000 km',
#   '1598 cc',
#   '124 hp',
#   'Benzin',
#   'Düz',
#   '7,2 lt',
#   '475.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2014',
#   '195.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '470.000 TL'],
#  ['Toyota',
#   '1.5 Dream',
#   '2023',
#   '2.000 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '800.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Flame X-Pack',
#   '2020',
#   '71.000 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '822.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2017',
#   '125.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '615.000 TL'],
#  ['Toyota',
#   '1.6 GLi Special',
#   '1998',
#   '339.000 km',
#   '1587 cc',
#   '114 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '265.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2015',
#   '128.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Düz',
#   '6,3 lt',
#   '590.000 TL'],
#  ['Toyota',
#   '1.5 Passion X-Pack',
#   '2022',
#   '6.050 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '930.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Plusline',
#   '2008',
#   '267.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '315.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2004',
#   '174.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '325.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '1999',
#   '92.000 km',
#   '1598 cc',
#   '110 hp',
#   'Benzin',
#   'Düz',
#   '7 lt',
#   '265.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1997',
#   '301.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '235.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1993',
#   '371.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '172.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2014',
#   '161.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '482.500 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2007',
#   '157.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '336.500 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2000',
#   '231.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '243.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2019',
#   '49.000 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '749.900 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2012',
#   '215.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '367.000 TL'],
#  ['Toyota',
#   '1.5 Dream',
#   '2021',
#   '6.500 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '769.900 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2022',
#   '15.000 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '899.900 TL'],
#  ['Toyota',
#   '1.6 GLi Special',
#   '1998',
#   '185.000 km',
#   nan,
#   '101 - 125 HP',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '255.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1996',
#   '309.000 km',
#   '1587 cc',
#   '114 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '195.000 TL'],
#  ['Toyota',
#   '1.6 Sol',
#   '2005',
#   '225.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,5 lt',
#   '270.000 TL'],
#  ['Toyota',
#   '1.6 Elegant',
#   '2009',
#   '161.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Yarı Otomatik',
#   '6,7 lt',
#   '397.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2016',
#   '99.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '530.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2014',
#   '62.000 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '470.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2016',
#   '66.058 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Düz',
#   '6,3 lt',
#   '593.750 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2010',
#   '256.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '318.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2017',
#   '123.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '505.000 TL'],
#  ['Toyota',
#   '1.6 Sol',
#   '2006',
#   '158.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '322.500 TL'],
#  ['Toyota',
#   '1.6 Sol',
#   '2006',
#   '219.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '325.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2009',
#   '148.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '395.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2006',
#   '328.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '220.000 TL'],
#  ['Toyota',
#   '1.6 Terra Special',
#   '2001',
#   '293.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '237.500 TL'],
#  ['Toyota',
#   '1.5 Dream',
#   '2022',
#   '6.101 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '838.000 TL'],
#  ['Toyota',
#   '1.6 Terra Special',
#   '2005',
#   '136.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '385.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1996',
#   '370.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '207.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2011',
#   '202.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '390.000 TL'],
#  ['Toyota',
#   '1.3 XE',
#   '1998',
#   '348.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '132.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2017',
#   '66.100 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '610.000 TL'],
#  ['Toyota',
#   '1.6 Sol',
#   '2006',
#   '85.000 km',
#   '1401 - 1600 cm3',
#   '101 - 125 HP',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '360.000 TL'],
#  ['Toyota',
#   '1.6 Linea Terra',
#   '2001',
#   '345.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '208.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2006',
#   '345.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '255.000 TL'],
#  ['Toyota',
#   '1.6 Dream',
#   '2020',
#   '20.600 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '754.000 TL'],
#  ['Toyota',
#   '1.3 XL',
#   '1992',
#   '99.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '205.000 TL'],
#  ['Toyota',
#   '1.6 Sol VVT-i',
#   '2004',
#   '321.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '255.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2015',
#   '112.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '540.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2019',
#   '29.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '739.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2020',
#   '22.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '660.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2012',
#   '157.500 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '410.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2016',
#   '97.600 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '495.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2017',
#   '68.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '523.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2006',
#   '197.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '307.500 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2005',
#   '89.000 km',
#   '1598 cc',
#   '110 hp',
#   'Benzin',
#   'Düz',
#   '7 lt',
#   '315.000 TL'],
#  ['Toyota',
#   '1.6 XEi Special',
#   '1998',
#   '264.500 km',
#   '1587 cc',
#   '115 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '258.500 TL'],
#  ['Toyota',
#   '1.3 XL',
#   '1994',
#   '122.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '195.000 TL'],
#  ['Toyota',
#   '1.5 Dream',
#   '2021',
#   '22.000 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '755.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2016',
#   '79.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '600.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2011',
#   '256.000 km',
#   '1364 cc',
#   '76 - 100 HP',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '290.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2021',
#   '65.000 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '752.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2008',
#   '150.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '410.000 TL'],
#  ['Toyota',
#   '1.6 Plusline',
#   '2007',
#   '261.000 km',
#   '1401 - 1600 cm3',
#   '101 - 125 HP',
#   'Benzin',
#   'Düz',
#   nan,
#   '260.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2015',
#   '124.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '459.000 TL'],
#  ['Toyota',
#   '1.6 Touch',
#   '2015',
#   '93.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '409.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2015',
#   '223.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '519.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2006',
#   '263.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,9 lt',
#   '319.900 TL'],
#  ['Toyota',
#   '1.6 Class',
#   '2008',
#   '175.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '385.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1997',
#   '278.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '175.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2015',
#   '131.850 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '545.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2023',
#   '282.000 km',
#   '1401 - 1600 cm3',
#   '101 - 125 HP',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '275.000 TL'],
#  ['Toyota',
#   '1.6 Sol',
#   '2004',
#   '299.600 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,5 lt',
#   '300.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Premium',
#   '2013',
#   '181.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '465.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2015',
#   '159.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '510.000 TL'],
#  ['Toyota',
#   '1.6 GL',
#   '1992',
#   '364.000 km',
#   '1401 - 1600 cm3',
#   '76 - 100 HP',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '140.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2014',
#   '93.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '555.000 TL'],
#  ['Toyota',
#   '1.6 Dream',
#   '2019',
#   '50.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '675.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1997',
#   '211.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '205.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1991',
#   '255.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '137.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Life',
#   '2013',
#   '149.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '415.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2010',
#   '240.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '297.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2017',
#   '115.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '598.000 TL'],
#  ['Toyota',
#   '1.6 Elegant',
#   '2011',
#   '188.000 km',
#   '1598 cc',
#   '124 hp',
#   'Benzin',
#   'Otomatik',
#   '7,1 lt',
#   '422.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2011',
#   '225.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '357.500 TL'],
#  ['Toyota',
#   '1.6 GL',
#   '1992',
#   '290.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '132.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1996',
#   '295.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '190.000 TL'],
#  ['Toyota',
#   '1.6 Touch',
#   '2016',
#   '84.200 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '557.750 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2011',
#   '106.450 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '490.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2015',
#   '71.661 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '480.000 TL'],
#  ['Toyota',
#   '1.3 XE',
#   '1997',
#   '232.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '145.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2017',
#   '103.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '612.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2013',
#   '69.000 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '440.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2020',
#   '30.711 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '743.750 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2016',
#   '95.500 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '485.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2014',
#   '110.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '419.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2008',
#   '148.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '355.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2015',
#   '111.581 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '569.750 TL'],
#  ['Toyota',
#   '1.8 Hybrid Passion X-Pack',
#   '2019',
#   '39.508 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '869.000 TL'],
#  ['Toyota',
#   '1.6 XLi',
#   '1997',
#   '278.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '235.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2016',
#   '61.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '542.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2012',
#   '181.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '445.000 TL'],
#  ['Toyota',
#   '1.6 Life',
#   '2018',
#   '26.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '600.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2011',
#   '153.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '377.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Premium',
#   '2016',
#   '184.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '590.000 TL'],
#  ['Toyota',
#   '1.33 Comfort',
#   '2011',
#   '140.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '375.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2014',
#   '67.400 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '519.900 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2013',
#   '187.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '450.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Class',
#   '2009',
#   '193.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '295.000 TL'],
#  ['Toyota',
#   '1.6 Dream',
#   '2020',
#   '39.250 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '725.000 TL'],
#  ['Toyota',
#   '1.6 Flame X Pack',
#   '2020',
#   '202.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '645.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2012',
#   '280.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '415.000 TL'],
#  ['Toyota',
#   '1.6 GLi Special',
#   '1998',
#   '318.000 km',
#   '1587 cc',
#   '114 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '270.000 TL'],
#  ['Toyota',
#   '1.6 Comfort',
#   '2008',
#   '170.000 km',
#   '1598 cc',
#   '124 hp',
#   'Benzin',
#   'Düz',
#   '6,9 lt',
#   '340.000 TL'],
#  ['Toyota',
#   '1.6 Flame X Pack',
#   '2020',
#   '35.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '850.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2007',
#   '258.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,9 lt',
#   '290.000 TL'],
#  ['Toyota',
#   '1.6 Luna',
#   '2000',
#   '258.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '215.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1996',
#   '299.900 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '205.000 TL'],
#  ['Toyota',
#   '1.6 Linea Sol',
#   '2003',
#   '270.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,9 lt',
#   '272.500 TL'],
#  ['Toyota',
#   '1.6 Touch',
#   '2015',
#   '111.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '568.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1997',
#   '275.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '232.500 TL'],
#  ['Toyota',
#   '1.6 Touch',
#   '2015',
#   '94.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Düz',
#   '6,3 lt',
#   '535.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2015',
#   '94.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '495.000 TL'],
#  ['Toyota',
#   '1.4 Terra VVT-i',
#   '2001',
#   '353.333 km',
#   '1398 cc',
#   '97 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,8 lt',
#   '205.000 TL'],
#  ['Toyota',
#   '1.4 Terra VVT-i',
#   '2001',
#   '240.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '233.000 TL'],
#  ['Toyota',
#   '1.6 GL',
#   '1993',
#   '392.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '162.500 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1997',
#   '446.365 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '197.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2008',
#   '110.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '360.000 TL'],
#  ['Toyota',
#   '1.3 Terra',
#   '1999',
#   '183.000 km',
#   '1332 cc',
#   '86 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '205.000 TL'],
#  ['Toyota',
#   '1.4 Terra',
#   '2001',
#   '380.000 km',
#   '1398 cc',
#   '97 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,8 lt',
#   '200.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1997',
#   '238.500 km',
#   '1587 cc',
#   '114 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '230.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2019',
#   '28.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '620.000 TL'],
#  ['Toyota',
#   '1.6 Premium',
#   '2013',
#   '129.500 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '589.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2009',
#   '285.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,9 lt',
#   '285.000 TL'],
#  ['Toyota',
#   '1.6 Premium',
#   '2015',
#   '114.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '538.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2015',
#   '26.500 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '513.000 TL'],
#  ['Toyota',
#   '1.3 XL',
#   '1998',
#   '254.500 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '155.000 TL'],
#  ['Toyota',
#   '1.3 XL',
#   '1998',
#   '320.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '155.000 TL'],
#  ['Toyota',
#   '1.33 Comfort',
#   '2011',
#   '179.500 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '365.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2009',
#   '262.100 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '285.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2017',
#   '47.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '780.000 TL'],
#  ['Toyota',
#   '1.6 Flame X Pack',
#   '2020',
#   '13.500 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '865.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2012',
#   '175.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '450.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1996',
#   '299.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '155.000 TL'],
#  ['Toyota',
#   '1.6 GL',
#   '1993',
#   '409.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '177.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2008',
#   '211.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '338.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Premium',
#   '2014',
#   '180.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '560.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2006',
#   '194.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '379.000 TL'],
#  ['Toyota',
#   '1.6 XLi',
#   '1992',
#   '530.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '115.000 TL'],
#  ['Toyota',
#   '1.6 Life',
#   '2018',
#   '63.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Düz',
#   '6,3 lt',
#   '615.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2005',
#   '245.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '319.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Class',
#   '2007',
#   '334.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '269.900 TL'],
#  ['Toyota',
#   '1.4 D-4D Sol',
#   '2007',
#   '260.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '295.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2008',
#   '245.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,9 lt',
#   '348.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2019',
#   '77.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '704.000 TL'],
#  ['Toyota',
#   '1.3 XL',
#   '1992',
#   '350.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '115.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1995',
#   '351.865 km',
#   '1587 cc',
#   '114 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   nan,
#   '180.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Class',
#   '2010',
#   '270.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '315.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2015',
#   '130.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '375.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2021',
#   '41.383 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '853.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2002',
#   '270.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,8 lt',
#   '265.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2021',
#   '48.396 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '863.000 TL'],
#  ['Toyota',
#   '1.3 ECO',
#   '1999',
#   '188.000 km',
#   '1332 cc',
#   '86 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '184.500 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1992',
#   '397.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '130.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Class',
#   '2010',
#   '298.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '303.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2009',
#   '204.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,9 lt',
#   '368.000 TL'],
#  ['Toyota',
#   '1.6 Linea Terra',
#   '2001',
#   '257.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '225.000 TL'],
#  ['Toyota',
#   '1.3 XE',
#   '1995',
#   '282.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '163.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2007',
#   '297.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '310.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2016',
#   '107.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '506.750 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2001',
#   '214.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '245.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2021',
#   '29.000 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '810.000 TL'],
#  ['Toyota',
#   '1.6 Elegant',
#   '2009',
#   '330.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '280.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2019',
#   '50.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '630.000 TL'],
#  ['Toyota',
#   '1.4 Linea Sol',
#   '2005',
#   '235.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '285.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2011',
#   '325.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '310.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2014',
#   '160.000 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '445.000 TL'],
#  ['Toyota',
#   '1.6 Life',
#   '2018',
#   '81.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Düz',
#   '6,3 lt',
#   '580.000 TL'],
#  ['Toyota',
#   '1.6 Elegant',
#   '2010',
#   '265.000 km',
#   '1598 cc',
#   '101 - 125 HP',
#   'LPG & Benzin',
#   'Otomatik',
#   '6 lt',
#   '315.000 TL'],
#  ['Toyota',
#   '1.6 Verso',
#   '2002',
#   '360.000 km',
#   '1601 - 1800 cm3',
#   '76 - 100 HP',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '245.900 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2017',
#   '74.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '515.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2017',
#   '184.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '525.000 TL'],
#  ['Toyota',
#   '1.6 Comfort Extra',
#   '2012',
#   '102.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,1 lt',
#   '450.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1995',
#   '402.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '235.500 TL'],
#  ['Toyota',
#   '1.6 Comfort',
#   '2010',
#   '196.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '410.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2016',
#   '55.862 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '565.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2014',
#   '170.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '565.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2011',
#   '176.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '417.500 TL'],
#  ['Toyota',
#   '1.3 XLi',
#   '1992',
#   '397.000 km',
#   '1296 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '115.000 TL'],
#  ['Toyota',
#   '1.6 Elegant',
#   '2008',
#   '169.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '407.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2016',
#   '70.000 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '495.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2015',
#   '39.000 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '480.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1991',
#   '275.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '165.000 TL'],
#  ['Toyota',
#   '1.6 Comfort',
#   '2009',
#   '230.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,2 lt',
#   '342.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1995',
#   '308.500 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '204.750 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2011',
#   '147.289 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '380.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2006',
#   '218.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '265.000 TL'],
#  ['Toyota',
#   '1.6 Terra Special',
#   '2005',
#   '139.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '310.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1992',
#   '500.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '145.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2019',
#   '64.000 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '697.500 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1997',
#   '342.000 km',
#   '1587 cc',
#   '105 hp',
#   'Benzin',
#   'Düz',
#   nan,
#   '178.000 TL'],
#  ['Toyota',
#   '1.3 Terra',
#   '1999',
#   '315.000 km',
#   '1332 cc',
#   '86 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '197.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2010',
#   '159.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '330.000 TL'],
#  ['Toyota',
#   '1.4 Terra',
#   '2006',
#   '175.000 km',
#   '1398 cc',
#   '97 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,7 lt',
#   '265.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2013',
#   '174.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '445.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2012',
#   '172.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '364.000 TL'],
#  ['Toyota',
#   '1.6 XLi',
#   '1997',
#   '358.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '175.000 TL'],
#  ['Toyota',
#   '1.6 Sol',
#   '2005',
#   '279.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '293.000 TL'],
#  ['Toyota',
#   '1.4 Terra',
#   '2001',
#   '265.000 km',
#   '1398 cc',
#   '97 hp',
#   'Benzin',
#   'Düz',
#   '6,8 lt',
#   '240.000 TL'],
#  ['Toyota',
#   '1.33 Comfort',
#   '2012',
#   '240.000 km',
#   '1329 cc',
#   '76 - 100 HP',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '300.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2013',
#   '156.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '469.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2015',
#   '87.020 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '575.000 TL'],
#  ['Toyota',
#   '1.6 Elegant',
#   '2007',
#   '189.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Yarı Otomatik',
#   '6,7 lt',
#   '330.000 TL'],
#  ['Toyota',
#   '1.6 Sol Special',
#   '2001',
#   '331.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '245.000 TL'],
#  ['Toyota',
#   '1.8 Linea Verso',
#   '2002',
#   '345.000 km',
#   '1801 - 2000 cm3',
#   '101 - 125 HP',
#   'LPG & Benzin',
#   'Otomatik',
#   nan,
#   '248.000 TL'],
#  ['Toyota',
#   '1.6 Elegant',
#   '2011',
#   '152.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '490.000 TL'],
#  ['Toyota',
#   '1.33 Comfort',
#   '2010',
#   '291.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '285.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2015',
#   '75.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '550.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1991',
#   '420.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '135.000 TL'],
#  ['Toyota',
#   '1.6 XLi',
#   '1996',
#   '215.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '210.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1992',
#   '354.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '154.500 TL'],
#  ['Toyota',
#   '1.6 Sol Special',
#   '2003',
#   '178.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7 lt',
#   '275.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2011',
#   '208.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '373.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2005',
#   '224.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '265.000 TL'],
#  ['Toyota',
#   '1.6 Sol VVT-i',
#   '2004',
#   '135.600 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '325.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2014',
#   '159.000 km',
#   '1329 cc',
# ...
#   'Düz',
#   '5,8 lt',
#   '450.000 TL'],
#  ['Toyota',
#   '1.6 Sol',
#   '2005',
#   '200.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '293.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2010',
#   '146.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '415.000 TL'],
#  ['Toyota',
#   '1.6 XEi Special',
#   '1998',
#   '303.000 km',
#   '1587 cc',
#   '115 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '225.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2006',
#   '201.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '307.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2012',
#   '107.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '450.000 TL'],
#  ['Toyota',
#   '1.6 Terra Special VVT-i',
#   '2005',
#   '164.818 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '335.000 TL'],
#  ['Toyota',
#   '1.6 Verso',
#   '2004',
#   '246.000 km',
#   '1401 - 1600 cm3',
#   '101 - 125 HP',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '310.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2007',
#   '274.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '235.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1996',
#   '290.000 km',
#   '1587 cc',
#   '114 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '186.990 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1995',
#   '241.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '215.000 TL'],
#  ['Toyota',
#   '1.3 LE',
#   '1995',
#   '300.000 km',
#   '1295 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '135.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2016',
#   '170.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '495.000 TL'],
#  ['Toyota',
#   '1.6 Comfort Extra',
#   '2010',
#   '162.000 km',
#   '1598 cc',
#   nan,
#   'LPG & Benzin',
#   'Otomatik',
#   '6 lt',
#   '420.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Terra',
#   '2006',
#   '230.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '300.000 TL'],
#  ['Toyota',
#   '1.3 ECO',
#   '1999',
#   '328.000 km',
#   '1332 cc',
#   '86 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '152.500 TL'],
#  ['Toyota',
#   '1.3 L',
#   '1992',
#   '290.000 km',
#   '1295 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '125.000 TL'],
#  ['Toyota',
#   '1.3 Terra',
#   '1999',
#   '250.000 km',
#   '1332 cc',
#   '86 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '182.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Sol',
#   '2006',
#   '267.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '198.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1993',
#   '240.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '139.000 TL'],
#  ['Toyota',
#   '1.33 Comfort',
#   '2011',
#   '133.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '402.000 TL'],
#  ['Toyota',
#   '1.33 Comfort',
#   '2011',
#   '154.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '367.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2022',
#   '12.000 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '855.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2014',
#   '180.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '480.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2009',
#   '320.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '285.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2012',
#   '275.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '283.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2016',
#   '102.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '474.500 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2020',
#   '26.300 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '632.999 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2011',
#   '195.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '305.000 TL'],
#  ['Toyota',
#   '1.4 Terra',
#   '2007',
#   '86.180 km',
#   '1398 cc',
#   '97 hp',
#   'Benzin',
#   'Düz',
#   '6,7 lt',
#   '310.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2008',
#   '314.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '286.500 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2006',
#   '166.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '337.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2011',
#   '195.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '376.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2008',
#   '250.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '325.000 TL'],
#  ['Toyota',
#   '1.3 L',
#   '1992',
#   '290.000 km',
#   '1295 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '125.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Elegant',
#   '2012',
#   '250.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '325.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2018',
#   '124.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '579.750 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2010',
#   '149.500 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '417.750 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2013',
#   '130.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '495.000 TL'],
#  ['Toyota',
#   '1.4 Terra',
#   '2001',
#   '329.000 km',
#   '1398 cc',
#   '97 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,8 lt',
#   '175.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2016',
#   '94.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '505.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2016',
#   '60.700 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '510.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort Extra',
#   '2011',
#   '157.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '355.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2001',
#   '400.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '178.000 TL'],
#  ['Toyota',
#   '1.6 Terra VVT-i',
#   '2005',
#   '178.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '290.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2020',
#   '15.500 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '715.000 TL'],
#  ['Toyota',
#   '1.6 Comfort',
#   '2010',
#   '183.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '413.500 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2012',
#   '202.000 km',
#   nan,
#   nan,
#   'Dizel',
#   'Düz',
#   nan,
#   '375.000 TL'],
#  ['Toyota',
#   '1.6 Dream',
#   '2020',
#   '22.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '780.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1998',
#   '312.458 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '198.500 TL'],
#  ['Toyota',
#   '1.6 Linea Terra',
#   '2003',
#   '193.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '305.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2012',
#   '122.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '415.000 TL'],
#  ['Toyota',
#   '1.6 Life',
#   '2018',
#   '68.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '597.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2018',
#   '56.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '675.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1997',
#   '285.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '210.000 TL'],
#  ['Toyota',
#   '1.6 Terra Special',
#   '2001',
#   '274.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '228.000 TL'],
#  ['Toyota',
#   '1.6 Touch',
#   '2017',
#   '61.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '570.000 TL'],
#  ['Toyota',
#   '1.3 ECO',
#   '1999',
#   '350.000 km',
#   '1332 cc',
#   '86 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '140.000 TL'],
#  ['Toyota',
#   '1.6 Flame X Pack',
#   '2019',
#   '61.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '740.000 TL'],
#  ['Toyota',
#   '1.33 Comfort',
#   '2015',
#   '113.000 km',
#   '1329 cc',
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '452.500 TL'],
#  ['Toyota',
#   '1.5 Dream',
#   '2021',
#   '50.800 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '720.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2015',
#   '51.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '585.000 TL'],
#  ['Toyota',
#   '1.6 XL',
#   '1993',
#   '232.000 km',
#   '1587 cc',
#   '95 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '177.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Advance',
#   '2013',
#   '185.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '415.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2019',
#   '49.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '640.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2018',
#   '88.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '650.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2017',
#   '71.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '520.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2015',
#   '37.750 km',
#   '1329 cc',
#   '99 hp',
#   'Benzin',
#   'Düz',
#   '5,8 lt',
#   '495.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2004',
#   '360.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '266.750 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2015',
#   '111.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '395.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '1999',
#   '271.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '195.000 TL'],
#  ['Toyota',
#   '1.5 Dream',
#   '2021',
#   '32.500 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '714.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1996',
#   '364.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '188.500 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2020',
#   '42.900 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '681.450 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2009',
#   '134.000 km',
#   '1365 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '305.000 TL'],
#  ['Toyota',
#   '1.6 Sol',
#   '2002',
#   '278.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '295.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2020',
#   '25.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '724.000 TL'],
#  ['Toyota',
#   '1.6 XEi',
#   '1997',
#   '360.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '220.000 TL'],
#  ['Toyota',
#   '1.5 Dream',
#   '2021',
#   '18.000 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '760.000 TL'],
#  ['Toyota',
#   '1.5 Flame X-Pack',
#   '2021',
#   '15.000 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '820.000 TL'],
#  ['Toyota',
#   '1.3 ECO',
#   '2000',
#   '308.000 km',
#   '1332 cc',
#   '86 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '145.000 TL'],
#  ['Toyota',
#   '1.5 Dream',
#   '2022',
#   '3.700 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '820.000 TL'],
#  ['Toyota',
#   '1.3 XL',
#   '1998',
#   '310.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '160.001 TL'],
#  ['Toyota',
#   '1.6 Comfort',
#   '2008',
#   '275.600 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Yarı Otomatik',
#   '6,7 lt',
#   '325.000 TL'],
#  ['Toyota',
#   '1.6 Active',
#   '2014',
#   '67.500 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,3 lt',
#   '520.000 TL'],
#  ['Toyota',
#   '1.3 XL',
#   '1995',
#   '241.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '147.500 TL'],
#  ['Toyota',
#   '1.6 Life',
#   '2018',
#   '40.200 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Düz',
#   '6,3 lt',
#   '583.500 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2016',
#   '47.728 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '520.000 TL'],
#  ['Toyota',
#   '1.5 Vision',
#   '2021',
#   '22.500 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '635.000 TL'],
#  ['Toyota',
#   '1.6 Sol Special',
#   '2001',
#   '270.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '270.000 TL'],
#  ['Toyota',
#   '1.3 XLi',
#   '1994',
#   '225.000 km',
#   '1332 cc',
#   '88 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '155.000 TL'],
#  ['Toyota',
#   '1.6 Advance',
#   '2015',
#   '99.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '575.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2008',
#   '166.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '338.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2010',
#   '252.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,9 lt',
#   '325.000 TL'],
#  ['Toyota',
#   '1.6 Vision',
#   '2020',
#   '38.000 km',
#   '1598 cc',
#   '132 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '715.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2018',
#   '135.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '538.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Flame X-Pack',
#   '2019',
#   '76.779 km',
#   '1800 cc',
#   '122 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   nan,
#   '825.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Flame X-Pack',
#   '2019',
#   '39.972 km',
#   '1800 cc',
#   '122 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   nan,
#   '848.000 TL'],
#  ['Toyota',
#   '1.6 Sport VVT-i',
#   '2005',
#   '302.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '255.000 TL'],
#  ['Toyota',
#   '1.6 Premium',
#   '2015',
#   '112.600 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '6,1 lt',
#   '525.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2018',
#   '107.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '605.750 TL'],
#  ['Toyota',
#   '1.4 D-4D Premium',
#   '2015',
#   '300.827 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,1 lt',
#   '440.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Flame X-Pack',
#   '2019',
#   '54.412 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '799.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2007',
#   '195.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,5 lt',
#   '335.000 TL'],
#  ['Toyota',
#   '1.6 Dream',
#   '2020',
#   '12.000 km',
#   '1598 cc',
#   '132 hp',
#   'Benzin',
#   'Otomatik',
#   '5,5 lt',
#   '800.000 TL'],
#  ['Toyota',
#   '1.6 Comfort',
#   '2012',
#   '183.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '455.000 TL'],
#  ['Toyota',
#   '1.5 Dream',
#   '2021',
#   '9.800 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '820.000 TL'],
#  ['Toyota',
#   '1.5 Vision',
#   '2021',
#   '6.100 km',
#   '1490 cc',
#   '125 hp',
#   'Benzin',
#   'Otomatik',
#   '5,8 lt',
#   '705.000 TL'],
#  ['Toyota',
#   '1.6 Comfort',
#   '2008',
#   '255.000 km',
#   '1598 cc',
#   '124 hp',
#   'LPG & Benzin',
#   'Yarı Otomatik',
#   '6,7 lt',
#   '363.000 TL'],
#  ['Toyota',
#   '1.33 Life',
#   '2015',
#   '89.000 km',
#   '1329 cc',
#   '99 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,8 lt',
#   '455.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Touch',
#   '2015',
#   '130.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,1 lt',
#   '470.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2011',
#   '246.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '350.000 TL'],
#  ['Toyota',
#   '1.8 Hybrid Dream',
#   '2019',
#   '84.000 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '718.500 TL'],
#  ['Toyota',
#   '1.8 Hybrid Flame X-Pack',
#   '2020',
#   '44.000 km',
#   '1798 cc',
#   '98 hp',
#   'Hibrit',
#   'Otomatik',
#   '3,5 lt',
#   '749.000 TL'],
#  ['Toyota',
#   '1.6 Terra',
#   '2001',
#   '284.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '230.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2008',
#   '205.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '320.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Comfort',
#   '2007',
#   '279.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '319.000 TL'],
#  ['Toyota',
#   '1.6 GLi',
#   '1996',
#   '280.000 km',
#   '1587 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '235.000 TL'],
#  ['Toyota',
#   '1.3 Terra',
#   '1999',
#   '340.000 km',
#   '1332 cc',
#   '86 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,9 lt',
#   '182.000 TL'],
#  ['Toyota',
#   '1.4 D-4D Sol',
#   '2007',
#   '307.000 km',
#   '1364 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '240.000 TL'],
#  ...]

# %%
len(features)
# Out:
# 1800

# %%
model
# Out:
# '1.5 dCi SportTourer Touch'

# %%
df_columns = ["Brand","Model","Year","Km","EngSize","Hp","Fuel","Gear Type",
             "Fuel Consumption ","Price"]

df = pd.DataFrame.from_records(features, columns=df_columns)

# %%
df.tail()
# Out:
#        Brand        Model  Year          Km  EngSize      Hp          Fuel  \
# 1795  Toyota    1.6 Dream  2020   24.500 km  1598 cc  132 hp        Benzin
# 1796  Toyota  1.6 Premium  2015   72.000 km  1598 cc  132 hp        Benzin
# 1797  Toyota          1.6  2005  270.000 km  1598 cc  110 hp  LPG & Benzin
# 1798  Toyota    1.5 Dream  2022    1.001 km  1490 cc  125 hp        Benzin
# 1799  Toyota   1.6 Vision  2020       86 km  1598 cc  132 hp        Benzin
#
#      Gear Type Fuel Consumption        Price
# 1795  Otomatik            5,5 lt  742.000 TL
# 1796  Otomatik            6,1 lt  620.000 TL
# 1797       Düz            7,2 lt  297.000 TL
# 1798  Otomatik            5,8 lt  801.000 TL
# 1799  Otomatik            5,5 lt  759.000 TL

# %%
df.head()
# Out:
#     Brand                      Model  Year          Km  EngSize      Hp  \
# 0  Toyota                 1.6 Vision  2020   80.000 km  1598 cc  132 hp
# 1  Toyota           1.8 Hybrid Dream  2021   41.060 km  1798 cc   98 hp
# 2  Toyota                    1.6 Sol  2005  157.000 km  1598 cc  110 hp
# 3  Toyota           1.8 Hybrid Dream  2021   40.389 km  1798 cc   98 hp
# 4  Toyota  1.8 Hybrid Passion X-Pack  2019  123.282 km  1798 cc   98 hp
#
#            Fuel Gear Type Fuel Consumption        Price
# 0  LPG & Benzin  Otomatik            5,5 lt  605.000 TL
# 1        Hibrit  Otomatik            3,5 lt  864.000 TL
# 2  LPG & Benzin  Otomatik            7,5 lt  367.500 TL
# 3        Hibrit  Otomatik            3,5 lt  853.000 TL
# 4        Hibrit  Otomatik            3,5 lt  848.000 TL

# %%
df.to_csv("seventh.csv")
