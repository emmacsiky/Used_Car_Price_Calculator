# %%
import numpy as np
import re
import pandas as pd

# %%
df1=pd.read_csv("./third.csv")
df2=pd.read_csv("./sixth.csv")
df3=pd.read_csv("./seventh.csv")
df4=pd.read_csv("./secondf.csv")
df6=pd.read_csv("./forth.csv")
df7=pd.read_csv("./firstdf.csv")
df8=pd.read_csv("./fifth.csv")
df9=pd.read_csv("./fece.csv")

cars=[df1,df2,df3,df4,df6,df7,df8,df9]
all_cars=pd.concat(cars)

# %%
all_cars.tail()
# Out:
#       Unnamed: 0    Brand                Model    Year          Km  \
# 2495        2495  Renault   1.5 dCi Expression  2011.0  285.000 km
# 2496        2496  Renault          1.3 TCe Joy  2020.0   13.500 km
# 2497        2497  Renault    1.5 dCi Dynamique  2009.0  360.000 km
# 2498        2498  Renault        1.5 dCi Touch  2017.0  114.000 km
# 2499        2499  Renault  1.5 dCi Authentique  2011.0  222.000 km
#
#               EngSize            Hp    Fuel      Gear Type Fuel Consumption   \
# 2495  1401 - 1600 cm3  101 - 125 HP   Dizel            Düz               NaN
# 2496          1332 cc        140 hp  Benzin            Düz            5,5 lt
# 2497          1461 cc        105 hp   Dizel            Düz            4,5 lt
# 2498          1461 cc        110 hp   Dizel  Yarı Otomatik            3,8 lt
# 2499          1461 cc         85 hp   Dizel            Düz            4,5 lt
#
#      Price
# 2495   NaN
# 2496   NaN
# 2497   NaN
# 2498   NaN
# 2499   NaN

# %%
all_cars.head()
# Out:
#    Unnamed: 0       Brand                Model    Year      Km  EngSize  Hp  \
# 0           0  Volkswagen    1.2 TDi Trendline  2012.0  170000     1199  75
# 1           1  Volkswagen  1.6 TDi Comfortline  2010.0  135000     1598  90
# 2           2  Volkswagen  1.6 TDi Comfortline  2018.0  130000     1598  95
# 3           3  Volkswagen  1.2 TSi Comfortline  2014.0  114000     1197  90
# 4           4  Volkswagen  1.4 TDi Comfortline  2017.0  214775     1422  90
#
#      Fuel      Gear Type Fuel Consumption        Price
# 0   Dizel            Düz            3,8 lt  325.000 TL
# 1   Dizel  Yarı Otomatik            4,3 lt  355.000 TL
# 2   Dizel  Yarı Otomatik            3,9 lt  600.000 TL
# 3  Benzin  Yarı Otomatik            4,7 lt  522.500 TL
# 4   Dizel  Yarı Otomatik            3,5 lt  469.750 TL

# %%
all_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16972 entries, 0 to 2499
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         16972 non-null  int64
#  1   Brand              16920 non-null  object
#  2   Model              16920 non-null  object
#  3   Year               1768 non-null   object
#  4   Km                 16920 non-null  object
#  5   EngSize            16661 non-null  object
#  6   Hp                 16649 non-null  object
#  7   Fuel               16920 non-null  object
#  8   Gear Type          16920 non-null  object
#  9   Fuel Consumption   15990 non-null  object
#  10  Price              14426 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 1.6+ MB

# %%
all_cars['Year'] = all_cars['Year'].str.extract("(\d+)").astype(float)

# %%
all_cars['Year'] = all_cars['Year'].str.extract("(\d{4})").astype(float)

# %%
all_cars["Year"]=all_cars["Year"].astype(float)

# %%
all_cars["Km"]=all_cars["Km"].str.replace(" km", "").str.replace(".", "").astype(float).astype(int)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11260\2285984959.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   all_cars["Km"]=all_cars["Km"].str.replace(" km", "").str.replace(".", "").astype(float).astype(int)

# %%
all_cars["Year"]=all_cars["Year"].str.replace("Yıl:\n\r\n "," ")

# %%
all_cars["EngSize"]=all_cars["EngSize"].str.replace(" cc", "")
all_cars["EngSize"]=all_cars["EngSize"].str.replace(" cm3", "")

# %%
all_cars["EngSize"]=all_cars["EngSize"].str.replace(" -", "")

# %%
all_cars['EngSize'] = all_cars['EngSize'].str.split(" ").str[0].astype(int)

# %%
all_cars["Hp"]=all_cars["Hp"].str.replace(" hp", "")

# %%
all_cars["Km"]=all_cars["Km"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [95], line 1
# ----> 1 all_cars["Km"]=all_cars["Km"].astype(float)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
all_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13567 entries, 0 to 1762
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         13567 non-null  int64
#  1   Brand              13567 non-null  object
#  2   Model              13567 non-null  object
#  3   Year               13567 non-null  object
#  4   Km                 13567 non-null  int32
#  5   EngSize            13567 non-null  object
#  6   Hp                 13567 non-null  object
#  7   Fuel               13567 non-null  object
#  8   Gear Type          13567 non-null  object
#  9   Fuel Consumption   13567 non-null  object
#  10  Price              13567 non-null  object
# dtypes: int32(1), int64(1), object(9)
# memory usage: 1.2+ MB

# %%
type(all_cars["Km"])
# Out:
# pandas.core.series.Series

# %%
all_cars["Hp"]=all_cars["Hp"].str.replace(" -", "")

# %%
all_cars['Hp'] = all_cars['Hp'].str.split(" ").str[0].astype(int)

# %%
all_cars.set_index("EngSize").filter(like='1201', axis=0)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Brand, Model, Year, Km, Hp, Fuel, Gear Type, Fuel Consumption , Price]
# Index: []

# %%
all_cars["Hp"]=all_cars["Hp"].str.rstrip(" ")

# %%
all_cars.set_index("Hp").filter(like='120', axis=0)
# Out:
#      Unnamed: 0    Brand                     Model    Year      Km  EngSize  \
# Hp
# 120          18     Fiat   1.6 Multijet Urban Plus  2019.0  123000  1598 cc
# 120          23     Fiat        1.6 Multijet Urban  2018.0  165000  1598 cc
# 120          28     Fiat  1.6 Multijet Lounge Plus  2017.0  119000  1598 cc
# 120          29     Fiat         1.6 Multijet Easy  2019.0   63961  1598 cc
# 120          36     Fiat     1.6 Multijet S-Design  2020.0    6764  1598 cc
# ..          ...      ...                       ...     ...     ...      ...
# 120        1884  Renault            1.2 Turbo Icon  2015.0   91000  1197 cc
# 120        1942  Renault             1.2 Turbo Joy  2018.0   25200  1197 cc
# 120        2238  Renault                  1.2 Icon  2015.0   73000  1197 cc
# 120        2430  Renault       1.2 Turbo Touchrome  2017.0   99000  1197 cc
# 120        2478  Renault            1.2 Turbo Icon  2016.0   12000  1197 cc
#
# ...

# %%
for i in all_cars["Hp"]:
    i.strip(" HP")
    Hp.
# Out:
#   Cell In [121], line 3
#     Hp.
#        ^
# SyntaxError: invalid syntax

# %%
all_cars.tail()
# Out:
#       Unnamed: 0    Brand                Model    Year          Km  \
# 2495        2495  Renault   1.5 dCi Expression  2011.0  285.000 km
# 2496        2496  Renault          1.3 TCe Joy  2020.0   13.500 km
# 2497        2497  Renault    1.5 dCi Dynamique  2009.0  360.000 km
# 2498        2498  Renault        1.5 dCi Touch  2017.0  114.000 km
# 2499        2499  Renault  1.5 dCi Authentique  2011.0  222.000 km
#
#               EngSize            Hp    Fuel      Gear Type Fuel Consumption   \
# 2495  1401 - 1600 cm3  101 - 125 HP   Dizel            Düz               NaN
# 2496          1332 cc        140 hp  Benzin            Düz            5,5 lt
# 2497          1461 cc        105 hp   Dizel            Düz            4,5 lt
# 2498          1461 cc        110 hp   Dizel  Yarı Otomatik            3,8 lt
# 2499          1461 cc         85 hp   Dizel            Düz            4,5 lt
#
#      Price
# 2495   NaN
# 2496   NaN
# 2497   NaN
# 2498   NaN
# 2499   NaN

# %%
all_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13567 entries, 0 to 1762
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         13567 non-null  int64
#  1   Brand              13567 non-null  object
#  2   Model              13567 non-null  object
#  3   Year               13567 non-null  object
#  4   Km                 13567 non-null  object
#  5   EngSize            13567 non-null  object
#  6   Hp                 13567 non-null  object
#  7   Fuel               13567 non-null  object
#  8   Gear Type          13567 non-null  object
#  9   Fuel Consumption   13567 non-null  object
#  10  Price              13567 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 1.2+ MB

# %%
all_cars=all_cars.dropna()

# %%
for col in all_cars.columns:
    all_cars[col] = all_cars[col].astype(str)

# %%
for col in all_cars.columns:
    if col not in ["Year", "Brand", "Fuel","Gear Type","Model"]:
        all_cars[col] = pd.to_numeric(all_cars[col].str.replace(r'[^\d.,]', '').str.replace(',', '.'), errors='coerce')
        if col in ["Km", "EngSize", "Hp"]:
            all_cars[col] = all_cars[col].astype(int)
        elif col == "Price":
            all_cars[col] = all_cars[col].astype(int)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11260\670463088.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   all_cars[col] = pd.to_numeric(all_cars[col].str.replace(r'[^\d.,]', '').str.replace(',', '.'), errors='coerce')
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In [56], line 5
#       3 all_cars[col] = pd.to_numeric(all_cars[col].str.replace(r'[^\d.,]', '').str.replace(',', '.'), errors='coerce')
#       4 if col in ["Km", "EngSize", "Hp"]:
# ----> 5     all_cars[col] = all_cars[col].astype(int)
#       6 elif col == "Price":
#       7     all_cars[col] = all_cars[col].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
# ...

# %%
all_cars
# Out:
#       Unnamed: 0       Brand                            Model    Year  \
# 0              0  Volkswagen                1.2 TDi Trendline  2012.0
# 1              1  Volkswagen              1.6 TDi Comfortline  2010.0
# 2              2  Volkswagen              1.6 TDi Comfortline  2018.0
# 3              3  Volkswagen              1.2 TSi Comfortline  2014.0
# 4              4  Volkswagen              1.4 TDi Comfortline  2017.0
# ...          ...         ...                              ...     ...
# 1758        1758  Volkswagen              1.6 TDi Comfortline  2012.0
# 1759        1759  Volkswagen   1.6 TDi BlueMotion Comfortline  2019.0
# 1760        1760  Volkswagen                1.6 TDi Trendline  2012.0
# 1761        1761  Volkswagen                  1.6 Comfortline  2002.0
# 1762        1762  Volkswagen  1.6 TDi BlueMotion Midline Plus  2014.0
#
#            Km  EngSize      Hp          Fuel      Gear Type Fuel Consumption   \
# ...
