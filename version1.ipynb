# %%
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup as bts
import pandas as pd 
import re
import numpy as np
import time

# %%
def getAndParseURL(url):
    result=requests.get(url,headers={"User-Agent":"Chrome/109.0.5414.120"})
    soup=bts(result.text,"html.parser")
    return soup

# %%
pages=["https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50"]
for page in range(2,51):
    pages.append("https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=" +str (page))
    
pages
# Out:
# ['https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=2',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=3',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=4',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=5',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=6',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=7',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=8',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=9',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=10',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=11',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=12',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=13',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=14',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=15',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=16',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=17',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=18',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=19',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=20',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=21',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=22',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=23',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=24',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=25',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=26',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=27',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=28',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=29',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=30',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=31',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=32',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=33',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=34',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=35',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=36',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=37',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=38',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=39',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=40',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=41',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=42',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=43',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=44',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=45',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=46',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=47',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=48',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=49',
#  'https://www.arabam.com/ikinci-el/otomobil/renault-clio?take=50&page=50']

# %%
ex=getAndParseURL("https://www.arabam.com/ilan/sahibinden-satilik-renault-clio-1-4-alize/sahibinden-renault-clio-1-4-8-valf-alize-2005-model/21844959")

# %%
ex.find("td",{"class":"listing-modelname pr"}).a.get("href")
# Out:
# '/ilan/sahibinden-satilik-renault-clio-1-5-dci-authentique/sahibinden-renault-clio-1-5-dci-authentique-2004-model/21579247'

# %%
cars=[]

for page in pages:
    html=getAndParseURL(page)
    for carlink in html.findAll("td",{"class":"listing-modelname pr"}):
        cars.append("https://www.arabam.com/"+carlink.a.get("href"))
        
cars
# Out:
# ['https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-touch/kale-otomotiv-den-2018-touch-dizel-otomatik-degisensiz/21907028',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-2-authentique/orjinal-aile-arabasi/21906665',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-0-tce-joy/2022-tam-otomatik-vites-hatasiz-boyasiz-turbo-motor-clio/21905162',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-joy/e-force-guvencesiyle-2016-dusuk-km-temiz-renault-clio-1-5-dci/21898316',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-touch/beyazkent-otomotiv-den-2018-clio-touch/21806590',
#  'https://www.arabam.com//ilan/sahibinden-satilik-renault-clio-1-2-turbo-joy/acili-sahibinden-hatasiz-boyasiz-tramersiz-dusuk-km/21877860',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-0-tce-joy/otomobil-renault-clio-hatchback-1-0-tce-joy-x-tronic/21859662',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-touch/renault-clio-1-5-dci-touch-2019-model/21870379',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-2-expression/gosterisli-renault-cli-1-2-16-v-lpgli-2005-model/21870007',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-0-tce-touch/hatasiz-boyasiz-2022-model-renault-clio-1-0-tce-touch-otomatik/21869762',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-0-tce-joy/abakay-otomotiv-den-hatasiz-boyasiz-clio-1-0-tce-18-faturali/21862559',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-sporttourer-joy/hatasiz-boyasiz-sifir-ayarinda/21859577',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-grandtour-extreme/renault-clio-1-5-dci-grandtour-extreme-2012-model-antalya/21851768',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-sporttourer-joy/galeriden-renault-clio-1-5-dci-sporttourer-joy-2013-model-mugla/21812256',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-joy/galeriden-renault-clio-1-5-dci-joy-2019-model-denizli/21803907',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-0-tce-touch/otomobil-renault-clio-hatchback-1-0-tce-touch-x-tronic/21797303',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-6-dynamique/renault-clio-16-valf-megane-1-motor/21320539',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-joy/galeriden-renault-clio-1-5-dci-joy-2018-model-mugla/21788818',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-extreme/masrafsiz-bakimli-2007-model/21637408',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-authentique/satlik-clio/21608579',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-icon/opsiyonlugaleriden-renault-clio-1-5-dci-icon-2014-model-denizli/21563511',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-alize/ablay-auto-dan-clio-symbol-alize-1-5-dci-dizel-2006-model/20776768',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-icon/2019-renault-clio-icon-dizel-otomatik-55-000-km-18-faturali/21048610',
#  'https://www.arabam.com//ilan/galeriden-satilik-renault-clio-1-5-dci-icon/galeriden-renault-clio-1-5-dci-icon-2017-model-aydin/21718553',
#  'https://www.arabam.com//ilan/sahibinden-satilik-renault-clio-1-2-icon

#  'https://www.arabam.com//ilan/sahibinden-satilik-renault-clio-1-5-dci-joy/sahibinden-renault-clio-1-5-dci-joy-2016-model/21846099',
#  'https://www.arabam.com//ilan/sahibinden-satilik-renault-clio-1-5-dci-touch/sahibinden-renault-clio-1-5-dci-touch-2017-model-96-000-km-beyaz/21846379',
#  ...]

# %%
len(cars)
# Out:
# 2500

# %%
ex.find("ul",{"class":"w100 cf mt12 detail-menu"})
# Out:
# <ul class="w100 cf mt12 detail-menu">
# <li class="bcd-list-item">
# <span class="bli-particle bold">İlan No:</span>
# <span class="bli-particle semi-bold">
#                                             21844959
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">İlan Tarihi:</span>
# <span class="bli-particle">
#                                             23 Ocak 2023
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Marka:</span>
# <span class="bli-particle">
#                                             Renault
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Seri:</span>
# <span class="bli-particle">
#                                             Clio
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Model:</span>
# <span class="bli-particle">
#                                             1.4 Alize
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Yıl:</span>
# <span class="bli-particle">
#                                             2005
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Kilometre:</span>
# <span class="bli-particle">
#                                             176.500 km
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Vites Tipi:</span>
# <span class="bli-particle">
#                                             Düz
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Yakıt Tipi:</span>
# <span class="bli-particle">
#                                             LPG &amp; Benzin
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Kasa Tipi:</span>
# <span class="bli-particle">
#                                             Sedan
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Motor Hacmi:</span>
# <span class="bli-particle">
#                                             1390 cc
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Motor Gücü:</span>
# <span class="bli-particle">
#                                             98 hp
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Çekiş:</span>
# <span class="bli-particle">
#                                             Önden Çekiş
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Ort. Yakıt Tüketimi:</span>
# <span class="bli-particle">
#                                             7 lt
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Yakıt Deposu:</span>
# <span class="bli-particle">
#                                             50 lt
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Boya-değişen:</span>
# <a class="bli-particle semi-bold" ng-click="self.resolveTabById('js-hook-for-observer-boyadegisen')">1 boyalı</a>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Takasa Uygun:</span>
# <span class="bli-particle" title="Takasa Uygun Değil">
#                                             Takasa Uygun Değil
#
#                                         </span>
# </li>
# <li class="bcd-list-item">
# <span class="bli-particle bold">Kimden:</span>
# <span class="bli-particle">
#                                             Sahibinden
#
#                                         </span>
# </li>
# </ul>

# %%
ex.find("ul",{"w100 cf mt12 detail-menu"}).find(text=re.compile("Marka")).findNext().text.strip()
# Out:
# 'Renault'

# %%
ex.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Yıl")).findNext().text.strip()
# Out:
# '2005'

# %%
ex.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Model")).findNext().text.strip()
# Out:
# '1.4 Alize'

# %%
features = []
for carl in cars:
    html=getAndParseURL(carl)
    try:
        brand =html.find("ul",{"w100 cf mt12 detail-menu"}).find(text=re.compile("Marka")).findNext().text.strip()
    except:
        brand = np.nan
    try:
        model=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Model")).findNext().text.strip()
    except:
        model=np.nan
    try:
        year=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Yıl")).findNext().text.strip()
    except:
        year=np.nan
    try:
        km=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Kilometre")).findNext().text.strip()
    except:
        km=np.nan
    try:
        engsize=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Motor Hacmi")).findNext().text.strip()
    except:
        engsize=np.nan
    try:
        hp=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Motor Gücü")).findNext().text.strip()
    except:
        hp=np.nan
    try:
        fuel=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Yakıt Tipi")).findNext().text.strip()
    except:
        fuel=np.nan
    try:
        gear=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Vites Tipi")).findNext().text.strip()
    except:
        gear=np.nan
    try:
        fuelcoms=html.find("ul",{"class":"w100 cf mt12 detail-menu"}).find(text=re.compile("Yakıt Tüketimi")).findNext().text.strip()
    except:
        fuelcoms=np.nan
    try:
        price=html.find("div",{"class":"color-red4 font-default-plusmore bold fl"}).text.strip()
    except:
        price=np.nan
                    
    features.append([brand,model,year,km,engsize,hp,fuel,gear,fuelcoms,price])
    
    time.sleep(2)

# %%
features
# Out:
# [['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '110.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '525.000 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2004',
#   '133.500 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '227.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2022',
#   '7.524 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '665.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2016',
#   '148.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '335.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '112.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '472.500 TL'],
#  ['Renault',
#   '1.2 Turbo Joy',
#   '2016',
#   '67.000 km',
#   '1197 cc',
#   '120 hp',
#   'Benzin',
#   'Yarı Otomatik',
#   '5,2 lt',
#   '405.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2021',
#   '26.000 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '545.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2019',
#   '91.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '435.000 TL'],
#  ['Renault',
#   '1.2 Expression',
#   '2004',
#   '249.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '185.000 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2022',
#   '6.100 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '619.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2022',
#   '20.000 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '549.500 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2016',
#   '120.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '385.000 TL'],
#  ['Renault',
#   '1.5 dCi Grandtour Extreme',
#   '2012',
#   '245.000 km',
#   '1461 cc',
#   '85 hp',
#   'Dizel',
#   'Düz',
#   '4,4 lt',
#   '250.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2013',
#   '206.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4 lt',
#   '335.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2019',
#   '67.500 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '445.000 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2020',
#   '58.000 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '559.000 TL'],
#  ['Renault',
#   '1.6 Dynamique',
#   '2002',
#   '294.000 km',
#   '1598 cc',
#   '105 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,8 lt',
#   '185.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '105.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '410.000 TL'],
#  ['Renault',
#   '1.5 dCi Extreme',
#   '2007',
#   '225.000 km',
#   '1401 - 1600 cm3',
#   '51 - 75 HP',
#   'Dizel',
#   'Düz',
#   nan,
#   '220.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2006',
#   '178.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '212.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2014',
#   '139.715 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '370.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2006',
#   '233.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '5 lt',
#   '165.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2019',
#   '55.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '537.500 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2017',
#   '140.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '515.000 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2013',
#   '122.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,5 lt',
#   '345.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2005',
#   '336.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '195.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2003',
#   '235.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,3 lt',
#   '215.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2005',
#   '170.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '252.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2016',
#   '19.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '41.000 TL'],
#  ['Renault',
#   '0.9 TCe Joy',
#   '2020',
#   '51.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '5 lt',
#   '435.000 TL'],
#  ['Renault',
#   '1.4 Expression',
#   '2004',
#   '360.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '210.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2016',
#   '230.470 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '350.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '130.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '389.950 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2023',
#   '6.001 km',
#   "1200 cm3' e kadar",
#   '76 - 100 HP',
#   'Benzin',
#   'Otomatik',
#   nan,
#   '676.500 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2009',
#   '240.000 km',
#   '1461 cc',
#   '68 hp',
#   'Dizel',
#   'Düz',
#   '4,5 lt',
#   '255.000 TL'],
#  ['Renault',
#   '0.9 TCe Icon',
#   '2013',
#   '78.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '4,5 lt',
#   '329.750 TL'],
#  ['Renault',
#   '1.4 RXT',
#   '2001',
#   '298.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,7 lt',
#   '210.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2017',
#   '108.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '469.000 TL'],
#  ['Renault',
#   '1.2 Extreme',
#   '2009',
#   '238.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '250.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '164.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '362.500 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2007',
#   '177.366 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '250.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2006',
#   '168.600 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '5 lt',
#   '249.000 TL'],
#  ['Renault',
#   '1.2 Extreme',
#   '2008',
#   '121.674 km',
#   '1149 cc',
#   '80 hp',
#   'LPG & Benzin',
#   'Yarı Otomatik',
#   '5,6 lt',
#   '310.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Icon',
#   '2013',
#   '180.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '355.000 TL'],
#  ['Renault',
#   '1.6 Extreme',
#   '2011',
#   '132.000 km',
#   '1598 cc',
#   '110 hp',
#   'Benzin',
#   'Otomatik',
#   '7,5 lt',
#   '329.000 TL'],
#  ['Renault',
#   '1.6 Extreme',
#   '2011',
#   '1.312.313 km',
#   '1598 cc',
#   '110 hp',
#   'Benzin',
#   'Otomatik',
#   '7,5 lt',
#   '3.123.123 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2013',
#   '88.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '362.000 TL'],
#  ['Renault',
#   '1.4 RN',
#   '1998',
#   '108.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,8 lt',
#   '152.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '200.000 km',
#   nan,
#   nan,
#   'Dizel',
#   'Düz',
#   nan,
#   '340.000 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2013',
#   '130.500 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '310.000 TL'],
#  ['Renault',
#   '1.4 RTA',
#   '2001',
#   '223.000 km',
#   '1390 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '6,8 lt',
#   '173.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2007',
#   '200.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,3 lt',
#   '225.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2017',
#   '151.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '418.500 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2014',
#   '321.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '310.000 TL'],
#  ['Renault',
#   '1.0 SCe Joy',
#   '2021',
#   '14.636 km',
#   '999 cc',
#   '72 hp',
#   'Benzin',
#   'Düz',
#   '4,9 lt',
#   '469.750 TL'],
#  ['Renault',
#   '0.9 TCe Joy',
#   '2020',
#   '59.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '5 lt',
#   '435.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2016',
#   '216.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '359.500 TL'],
#  ['Renault',
#   '1.6 RXT',
#   '2000',
#   '233.000 km',
#   '1598 cc',
#   '90 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '180.000 TL'],
#  ['Renault',
#   '1.4 RXT',
#   '2001',
#   '324.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,7 lt',
#   '195.000 TL'],
#  ['Renault',
#   '1.5 dCi Extreme',
#   '2010',
#   '240.000 km',
#   '1461 cc',
#   '85 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '288.000 TL'],
#  ['Renault',
#   '1.2 SportTourer Joy',
#   '2014',
#   '82.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '335.000 TL'],
#  ['Renault',
#   '1.4 RN',
#   '1997',
#   '250.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '109.500 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2005',
#   '271.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '175.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '81.300 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '425.000 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2005',
#   '235.000 km',
#   '1149 cc',
#   '65 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '250.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2022',
#   '6.001 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '625.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2014',
#   '147.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '420.000 TL'],
#  ['Renault',
#   '1.2 Turbo Icon',
#   '2016',
#   '97.000 km',
#   nan,
#   nan,
#   'Benzin',
#   'Düz',
#   nan,
#   '485.000 TL'],
#  ['Renault',
#   '1.2 SportTourer Joy',
#   '2016',
#   '185.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,5 lt',
#   '319.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2018',
#   '104.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '557.500 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2022',
#   '200 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '595.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2016',
#   '85.700 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '472.500 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2022',
#   '0 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '666.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2019',
#   '79.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '568.000 TL'],
#  ['Renault',
#   '1.4 Alize',
#   '2006',
#   '64.800 km',
#   '1390 cc',
#   '98 hp',
#   'Benzin',
#   'Düz',
#   '7 lt',
#   '259.000 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2020',
#   '72.000 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '560.000 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2020',
#   '54.000 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '595.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '122.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '396.500 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '94.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '430.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '83.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '485.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2006',
#   '264.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '5 lt',
#   '215.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2005',
#   '152.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '220.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2013',
#   '144.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '385.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2014',
#   '141.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '397.500 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '125.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '390.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2000',
#   '252.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '192.500 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2008',
#   '203.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '239.500 TL'],
#  ['Renault',
#   '0.9 TCe Joy',
#   '2020',
#   '16.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '5 lt',
#   '435.000 TL'],
#  ['Renault',
#   '1.4 RXT',
#   '2001',
#   '101.000 km',
#   '1390 cc',
#   '98 hp',
#   'Benzin',
#   'Otomatik',
#   '6,7 lt',
#   '243.000 TL'],
#  ['Renault',
#   '1.2 Expression',
#   '2010',
#   '145.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '286.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Touch',
#   '2018',
#   '117.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '488.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '172.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '399.999 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '150.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '347.000 TL'],
#  ['Renault',
#   '1.4',
#   '2001',
#   '263.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '172.500 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2003',
#   '260.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '170.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2001',
#   '205.500 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '175.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Touch',
#   '2018',
#   '158.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '449.750 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2018',
#   '55.642 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '445.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2013',
#   '285.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '255.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2012',
#   '269.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '319.000 TL'],
#  ['Renault',
#   '1.6 RXT',
#   '2000',
#   '249.900 km',
#   '1598 cc',
#   '90 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '182.500 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2014',
#   '246.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4 lt',
#   '330.000 TL'],
#  ['Renault',
#   '1.0 TCe Icon',
#   '2022',
#   '6.600 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '730.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2013',
#   '268.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '265.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '212.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '350.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2006',
#   '356.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '205.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '175.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '387.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2006',
#   '333.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '185.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2000',
#   '199.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '165.000 TL'],
#  ['Renault',
#   '1.2 Extreme',
#   '2008',
#   '185.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '265.500 TL'],
#  ['Renault',
#   '1.4 Alize',
#   '2006',
#   '229.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '195.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '149.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '355.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '109.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '343.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2012',
#   '130.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '290.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2019',
#   '96.380 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '410.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2016',
#   '146.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '385.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '102.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '470.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2000',
#   '198.350 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '175.000 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2016',
#   '95.000 km',
#   '1197 cc',
#   '120 hp',
#   'Benzin',
#   'Yarı Otomatik',
#   '5,2 lt',
#   '426.500 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2015',
#   '136.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '465.900 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2014',
#   '120.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '425.000 TL'],
#  ['Renault',
#   '1.2 Turbo Icon',
#   '2013',
#   '192.500 km',
#   '1197 cc',
#   '120 hp',
#   'LPG & Benzin',
#   'Yarı Otomatik',
#   '5,2 lt',
#   '405.000 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2014',
#   '122.500 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '350.000 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2004',
#   '314.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '230.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2013',
#   '160.750 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '365.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '135.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '369.950 TL'],
#  ['Renault',
#   '1.4 RN',
#   '1997',
#   '160.000 km',
#   '1201 - 1400 cm3',
#   '76 - 100 HP',
#   'LPG & Benzin',
#   'Otomatik',
#   nan,
#   '144.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2017',
#   '77.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '450.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2004',
#   '269.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '187.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2001',
#   '317.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '186.500 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '124.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '497.500 TL'],
#  ['Renault',
#   '1.2 Extreme',
#   '2011',
#   '111.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '305.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2016',
#   '87.500 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '419.500 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2007',
#   '235.000 km',
#   '1461 cc',
#   '80 hp',
#   'Dizel',
#   'Düz',
#   '4,6 lt',
#   '225.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2004',
#   '309.500 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '170.000 TL'],
#  ['Renault',
#   '1.0 SCe Joy',
#   '2022',
#   '23.500 km',
#   nan,
#   nan,
#   'Benzin',
#   'Düz',
#   nan,
#   '515.000 TL'],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['Renault',
#   '1.0 TCe Icon',
#   '2021',
#   '14.500 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '625.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2005',
#   '222.300 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '227.000 TL'],
#  ['Renault',
#   '1.5 dCi Expression',
#   '2006',
#   '289.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '165.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2013',
#   '190.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,5 lt',
#   '355.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2017',
#   '132.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '410.000 TL'],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['Renault',
#   '1.6 Executive',
#   '2011',
#   '113.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,5 lt',
#   '405.000 TL'],
#  ['Renault',
#   '0.9 TCe Joy',
#   '2020',
#   '136.568 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '5 lt',
#   '370.000 TL'],
#  ['Renault',
#   '1.5 dCi Extreme',
#   '2012',
#   '173.000 km',
#   '1461 cc',
#   '85 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '4,8 lt',
#   '367.500 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2004',
#   '199.086 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '187.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '91.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '310.000 TL'],
#  ['Renault',
#   '1.4 RXT',
#   '2002',
#   '136.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,7 lt',
#   '241.000 TL'],
#  ['Renault',
#   '1.4 RN',
#   '1997',
#   '248.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '118.000 TL'],
#  ['Renault',
#   '1.4 Expression',
#   '2002',
#   '262.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '178.000 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2022',
#   '1.000 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '690.000 TL'],
#  ['Renault',
#   '1.0 SCe Joy',
#   '2021',
#   '56.000 km',
#   '999 cc',
#   '65 hp',
#   'Benzin',
#   'Düz',
#   '4,9 lt',
#   '430.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2017',
#   '88.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '475.000 TL'],
#  ['Renault',
#   '0.9 TCe Touch',
#   '2019',
#   '48.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '4,5 lt',
#   '460.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '200.080 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '320.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2004',
#   '11.114 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '165.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '168.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '399.950 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '112.348 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '509.900 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '110.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4 lt',
#   '365.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2019',
#   '156.377 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '500.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2005',
#   '254.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '200.000 TL'],
#  ['Renault',
#   '0.9 TCe Joy',
#   '2020',
#   '15.299 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '5 lt',
#   '460.000 TL'],
#  ['Renault',
#   '1.2 Turbo Icon',
#   '2014',
#   '85.950 km',
#   '1197 cc',
#   '120 hp',
#   'Benzin',
#   'Yarı Otomatik',
#   '5,2 lt',
#   '459.900 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2017',
#   '63.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '455.000 TL'],
#  ['Renault',
#   '0.9 TCe Icon',
#   '2013',
#   '114.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '4,5 lt',
#   '339.000 TL'],
#  ['Renault',
#   '1.5 dCi Grandtour Executive',
#   '2011',
#   '170.000 km',
#   '1461 cc',
#   '85 hp',
#   'Dizel',
#   'Düz',
#   '4,4 lt',
#   '304.900 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '93.280 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '388.500 TL'],
#  ['Renault',
#   '1.5 dCi Authentique Edition',
#   '2012',
#   '170.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4,4 lt',
#   '307.000 TL'],
#  ['Renault',
#   '1.6 RTE',
#   '1999',
#   '277.000 km',
#   '1598 cc',
#   '90 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '170.750 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '155.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '360.000 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2021',
#   '17.500 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '608.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '125.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '396.000 TL'],
#  ['Renault',
#   '1.6 RXT',
#   '2000',
#   '264.200 km',
#   '1598 cc',
#   '90 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '142.000 TL'],
#  ['Renault',
#   '1.4 RXT',
#   '2002',
#   '300.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,7 lt',
#   '172.500 TL'],
#  ['Renault',
#   '1.3 TCe Touch',
#   '2020',
#   '14.000 km',
#   '1332 cc',
#   '130 hp',
#   'Benzin',
#   'Yarı Otomatik',
#   '5,2 lt',
#   '617.000 TL'],
#  ['Renault',
#   '1.4 RTA',
#   '2000',
#   '191.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,8 lt',
#   '173.000 TL'],
#  ['Renault',
#   '1.2 Touch',
#   '2012',
#   '63.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,5 lt',
#   '356.000 TL'],
#  ['Renault',
#   '1.4 Privilege',
#   '2004',
#   '225.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,7 lt',
#   '250.000 TL'],
#  ['Renault',
#   '0.9 TCe Icon',
#   '2012',
#   '117.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '4,5 lt',
#   '348.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2019',
#   '60.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '539.900 TL'],
#  ['Renault',
#   '1.0 SCe Joy',
#   '2020',
#   '34.913 km',
#   '999 cc',
#   '72 hp',
#   'Benzin',
#   'Düz',
#   '4,9 lt',
#   '467.900 TL'],
#  ['Renault',
#   '1.4 Dynamique',
#   '2006',
#   '303.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,6 lt',
#   '185.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2022',
#   '5.500 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '645.000 TL'],
#  ['Renault',
#   '1.2 Turbo Touchrome',
#   '2017',
#   '110.000 km',
#   '1197 cc',
#   '120 hp',
#   'LPG & Benzin',
#   'Yarı Otomatik',
#   '5,2 lt',
#   '502.000 TL'],
#  ['Renault',
#   '1.4 RTA',
#   '2001',
#   '175.000 km',
#   '1390 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '6,8 lt',
#   '190.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '166.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '390.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2018',
#   '150.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '484.750 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2006',
#   '261.000 km',
#   '1401 - 1600 cm3',
#   '51 - 75 HP',
#   'Dizel',
#   'Düz',
#   nan,
#   '250.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2005',
#   '301.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '210.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2007',
#   '260.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '237.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2018',
#   '89.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '555.000 TL'],
#  ['Renault',
#   '1.5 dCi Expression',
#   '2003',
#   '310.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '179.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2023',
#   '6.001 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '634.000 TL'],
#  ['Renault',
#   '1.5 dCi Dynamique',
#   '2009',
#   '251.000 km',
#   '1461 cc',
#   '85 hp',
#   'Dizel',
#   'Düz',
#   '4,4 lt',
#   '250.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2014',
#   '131.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '412.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2001',
#   '235.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '173.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2005',
#   '242.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '210.000 TL'],
#  ['Renault',
#   '1.2 Expression',
#   '2010',
#   '165.000 km',
#   '1149 cc',
#   '80 hp',
#   'Benzin',
#   'Yarı Otomatik',
#   '5,6 lt',
#   '345.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '138.738 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '496.900 TL'],
#  ['Renault',
#   '1.4 Dynamique',
#   '2003',
#   '250.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '150.000 TL'],
#  ['Renault',
#   '1.5 BlueDCI Joy',
#   '2020',
#   '80.300 km',
#   '1461 cc',
#   '85 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '532.000 TL'],
#  ['Renault',
#   '1.2 SportTourer Joy',
#   '2014',
#   '145.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '349.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2016',
#   '99.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '390.000 TL'],
#  ['Renault',
#   '1.5 dCi Extreme',
#   '2008',
#   '193.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '270.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2013',
#   '168.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,5 lt',
#   '325.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2017',
#   '94.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '500.000 TL'],
#  ['Renault',
#   '1.2 Grandtour Night & Day',
#   '2011',
#   '213.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '225.000 TL'],
#  ['Renault',
#   '1.3 TCe Icon',
#   '2020',
#   '33.800 km',
#   '1332 cc',
#   '130 hp',
#   'Benzin',
#   'Yarı Otomatik',
#   '5,2 lt',
#   '650.000 TL'],
#  ['Renault',
#   '1.2 SportTourer Icon',
#   '2013',
#   '105.000 km',
#   '1197 cc',
#   '120 hp',
#   'Benzin',
#   'Yarı Otomatik',
#   '5,2 lt',
#   '420.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2021',
#   '16.800 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '567.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2013',
#   '150.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,5 lt',
#   '310.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '161.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '419.500 TL'],
#  ['Renault',
#   '1.2 Extreme',
#   '2010',
#   '104.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '298.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2018',
#   '86.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '424.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2019',
#   '99.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '432.000 TL'],
#  ['Renault',
#   '1.6 Grandtour Night & Day',
#   '2012',
#   '151.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,8 lt',
#   '442.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2002',
#   '290.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '154.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2013',
#   '226.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '315.000 TL'],
#  ['Renault',
#   '1.5 dCi Grandtour Night & Day',
#   '2012',
#   '144.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '4,4 lt',
#   '350.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '255.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '340.000 TL'],
#  ['Renault',
#   '1.4 RT',
#   '1996',
#   '225.000 km',
#   '1390 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   nan,
#   '150.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2000',
#   '206.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '180.000 TL'],
#  ['Renault',
#   '0.9 TCe Icon',
#   '2013',
#   '125.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '4,5 lt',
#   '365.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '170.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '370.000 TL'],
#  ['Renault',
#   '1.4 RTA',
#   '1998',
#   '187.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,8 lt',
#   '135.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '252.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '305.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2004',
#   '407.000 km',
#   '1461 cc',
#   '80 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '149.500 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '182.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '360.000 TL'],
#  ['Renault',
#   '1.6 RTE',
#   '1999',
#   '199.000 km',
#   '1401 - 1600 cm3',
#   '76 - 100 HP',
#   'Benzin',
#   'Düz',
#   nan,
#   '210.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2001',
#   '268.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '178.000 TL'],
#  ['Renault',
#   '1.6 Dynamique',
#   '2002',
#   '224.000 km',
#   '1598 cc',
#   '107 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '225.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2018',
#   '4.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '492.000 TL'],
#  ['Renault',
#   '1.0 SCe Joy',
#   '2020',
#   '12.000 km',
#   '999 cc',
#   '72 hp',
#   'Benzin',
#   'Düz',
#   '4,9 lt',
#   '465.000 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2020',
#   '40.850 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '525.000 TL'],
#  ['Renault',
#   '1.6 RTE',
#   '2000',
#   '315.000 km',
#   '1598 cc',
#   '90 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '235.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2021',
#   '32.000 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '545.900 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2019',
#   '70.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '536.900 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Touch',
#   '2018',
#   '127.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '432.500 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2022',
#   '9.000 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '605.900 TL'],
#  ['Renault',
#   '1.5 dCi Extreme',
#   '2011',
#   '175.900 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,5 lt',
#   '285.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2002',
#   '249.500 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '175.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2004',
#   '282.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '192.500 TL'],
#  ['Renault',
#   '0.9 TCe Touch',
#   '2020',
#   '25.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '5 lt',
#   '448.500 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2016',
#   '115.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '490.000 TL'],
#  ['Renault',
#   '1.4 RTA',
#   '2000',
#   '262.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '178.500 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2014',
#   '140.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '385.500 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2000',
#   '237.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '170.000 TL'],
#  ['Renault',
#   '1.5 dCi Dynamique',
#   '2005',
#   '227.000 km',
#   '1461 cc',
#   '86 hp',
#   'Dizel',
#   'Düz',
#   '4,4 lt',
#   '187.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2015',
#   '181.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '380.000 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2020',
#   '39.000 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Düz',
#   '4,3 lt',
#   '505.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2022',
#   '9.300 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '595.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2022',
#   '1.010 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '657.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2001',
#   '170.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '175.000 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2022',
#   '1.001 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '654.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2000',
#   '269.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '183.500 TL'],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2006',
#   '190.572 km',
#   '1461 cc',
#   '80 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '228.500 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2015',
#   '106.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '418.000 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2011',
#   '259.000 km',
#   '1149 cc',
#   '65 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '240.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2007',
#   '296.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '232.000 TL'],
#  ['Renault',
#   '1.5 dCi Extreme',
#   '2008',
#   '300.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '185.000 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2007',
#   '128.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '270.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2015',
#   '162.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '340.000 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2013',
#   '85.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '395.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2006',
#   '221.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '190.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '145.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '390.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2009',
#   '195.000 km',
#   '1461 cc',
#   '68 hp',
#   'Dizel',
#   'Düz',
#   '4,5 lt',
#   '268.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2017',
#   '75.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '410.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2019',
#   '85.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '444.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '79.663 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '529.900 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '141.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '393.000 TL'],
#  ['Renault',
#   '1.4 Alize',
#   '2006',
#   '86.000 km',
#   '1390 cc',
#   '98 hp',
#   'Benzin',
#   'Düz',
#   '7 lt',
#   '263.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2005',
#   '285.000 km',
#   '1461 cc',
#   '80 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '169.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2017',
#   '209.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '402.500 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2020',
#   '26.600 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '584.750 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2014',
#   '203.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4 lt',
#   '318.000 TL'],
#  ['Renault',
#   '1.4 RTA',
#   '1999',
#   '198.444 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,8 lt',
#   '195.000 TL'],
#  ['Renault',
#   '1.2 Touch',
#   '2012',
#   '134.848 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '354.950 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2006',
#   '299.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Yarı Otomatik',
#   '5,8 lt',
#   '228.500 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '191.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '399.950 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2016',
#   '160.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '459.950 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '203.500 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '365.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '132.135 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '489.900 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2012',
#   '69.684 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '425.000 TL'],
#  ['Renault',
#   '1.2 Extreme',
#   '2012',
#   '93.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '335.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2013',
#   '105.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,5 lt',
#   '400.000 TL'],
#  ['Renault',
#   '1.4 RTA',
#   '2000',
#   '293.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,8 lt',
#   '184.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2022',
#   '6.161 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '615.000 TL'],
#  ['Renault',
#   '1.6 Extreme',
#   '2011',
#   '126.000 km',
#   '1598 cc',
#   '110 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,5 lt',
#   '350.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2014',
#   '185.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4 lt',
#   '295.000 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2017',
#   '27.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '429.750 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2008',
#   '258.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '230.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2014',
#   '143.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4 lt',
#   '337.500 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2006',
#   '360.000 km',
#   '1461 cc',
#   '80 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '195.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Touch',
#   '2015',
#   '214.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '353.000 TL'],
#  ['Renault',
#   '1.4 RN',
#   '2001',
#   '268.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '185.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2019',
#   '105.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '455.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2004',
#   '99.000 km',
#   '1390 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '7,1 lt',
#   '244.500 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2016',
#   '179.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '360.000 TL'],
#  ['Renault',
#   '1.4 Alize',
#   '2006',
#   '176.442 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '255.000 TL'],
#  ['Renault',
#   '1.4 Dynamique',
#   '2007',
#   '161.000 km',
#   '1390 cc',
#   '100 hp',
#   'Benzin',
#   'Düz',
#   '6,7 lt',
#   '264.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '139.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '470.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2005',
#   '330.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '198.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2005',
#   '305.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '170.000 TL'],
#  ['Renault',
#   '1.4 Privilege',
#   '2004',
#   '280.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,7 lt',
#   '195.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '141.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '393.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '175.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '378.500 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '86.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '380.000 TL'],
#  ['Renault',
#   '1.8 RSi',
#   '1997',
#   '300.000 km',
#   '1794 cc',
#   '109 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '115.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2002',
#   '305.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,3 lt',
#   '175.000 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2014',
#   '114.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '315.500 TL'],
#  ['Renault',
#   '1.6 RXT',
#   '2000',
#   '260.600 km',
#   '1598 cc',
#   '90 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '165.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Touch',
#   '2019',
#   '92.600 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '512.750 TL'],
#  ['Renault',
#   '1.0 SCe Joy',
#   '2022',
#   '8 km',
#   '999 cc',
#   '65 hp',
#   'Benzin',
#   'Düz',
#   '4,9 lt',
#   '490.000 TL'],
#  ['Renault',
#   '1.5 BlueDCI Joy',
#   '2020',
#   '47.837 km',
#   '1461 cc',
#   '85 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '580.000 TL'],
#  ['Renault',
#   '0.9 TCe Sport Tourer Joy',
#   '2020',
#   '57.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '5,1 lt',
#   '430.000 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2012',
#   '43.250 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '335.000 TL'],
#  ['Renault',
#   '1.4 RN',
#   '1997',
#   '225.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '95.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2015',
#   '88.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '380.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2019',
#   '154.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '464.900 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '136.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '447.900 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '117.883 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '390.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2006',
#   '270.000 km',
#   '1461 cc',
#   '80 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '183.000 TL'],
#  ['Renault',
#   '1.2 Extreme',
#   '2011',
#   '130.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '270.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '190.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '389.750 TL'],
#  ['Renault',
#   '1.6 RTE',
#   '2000',
#   '246.000 km',
#   '1598 cc',
#   '90 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '7,8 lt',
#   '240.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '275.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '345.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2012',
#   '171.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '395.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2008',
#   '322.000 km',
#   '1461 cc',
#   '68 hp',
#   'Dizel',
#   'Düz',
#   '4,6 lt',
#   '180.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2004',
#   '243.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '198.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Icon',
#   '2016',
#   '210.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '435.000 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2008',
#   '290.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '220.000 TL'],
#  ['Renault',
#   '1.4 Expression',
#   '2003',
#   '205.000 km',
#   '1201 - 1400 cm3',
#   '51 - 75 HP',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '235.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Touch',
#   '2019',
#   '85.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '495.000 TL'],
#  ['Renault',
#   '1.6 Dynamique',
#   '2003',
#   '290.000 km',
#   '1201 - 1400 cm3',
#   '76 - 100 HP',
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '190.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2005',
#   '229.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '215.000 TL'],
#  ['Renault',
#   '1.4 Dynamique',
#   '2004',
#   '134.000 km',
#   '1390 cc',
#   '98 hp',
#   'Benzin',
#   'Otomatik',
#   '6,7 lt',
#   '297.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2000',
#   '216.850 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '213.500 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2019',
#   '98.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '479.500 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '145.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '385.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2015',
#   '157.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '362.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2015',
#   '110.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '474.000 TL'],
#  ['Renault',
#   '1.2 Extreme',
#   '2012',
#   '132.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '310.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2004',
#   '223.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '195.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2005',
#   '254.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '188.500 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2015',
#   '71.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '450.000 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2007',
#   '141.500 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '266.000 TL'],
#  ['Renault',
#   '1.5 dCi Extreme',
#   '2009',
#   '194.500 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '257.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Icon',
#   '2016',
#   '142.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '445.000 TL'],
#  ['Renault',
#   '1.2 Extreme',
#   '2008',
#   '116.000 km',
#   '1149 cc',
#   '80 hp',
#   'Benzin',
#   'Yarı Otomatik',
#   '5,6 lt',
#   '305.000 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2005',
#   '161.000 km',
#   '1149 cc',
#   '65 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '215.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2005',
#   '108.000 km',
#   '1390 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '7,1 lt',
#   '247.500 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2018',
#   '204.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '458.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2016',
#   '178.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '314.500 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2015',
#   '99.900 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '385.500 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2008',
#   '253.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '245.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '131.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '405.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2004',
#   '131.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '210.000 TL'],
#  ['Renault',
#   '1.5 dCi Extreme',
#   '2008',
#   '366.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '5 lt',
#   '250.000 TL'],
#  ['Renault',
# ...
#   '98 hp',
#   'LPG & Benzin',
#   'Yarı Otomatik',
#   '7,3 lt',
#   '240.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2013',
#   '260.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,5 lt',
#   '400.000 TL'],
#  ['Renault',
#   '1.5 dCi Grandtour Authentique',
#   '2010',
#   '198.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,5 lt',
#   '310.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2015',
#   '131.500 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '345.000 TL'],
#  ['Renault',
#   '1.4 RN',
#   '2000',
#   '271.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '157.000 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2013',
#   '35.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '440.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2010',
#   '203.000 km',
#   '1461 cc',
#   '70 hp',
#   'Dizel',
#   'Düz',
#   '4,5 lt',
#   '264.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '93.500 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '517.500 TL'],
#  ['Renault',
#   '1.5 dCi Expression',
#   '2006',
#   '189.500 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '244.950 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2015',
#   '145.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '385.000 TL'],
#  ['Renault',
#   '1.4 Privilege',
#   '2004',
#   '198.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,7 lt',
#   '285.000 TL'],
#  ['Renault',
#   '1.4 Privilege',
#   '2004',
#   '240.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Otomatik',
#   '6,7 lt',
#   '280.000 TL'],
#  ['Renault',
#   '1.4 RTA',
#   '2001',
#   '238.600 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,8 lt',
#   '186.500 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2017',
#   '190.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '424.500 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2016',
#   '185.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '360.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2006',
#   '268.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '210.000 TL'],
#  ['Renault',
#   '1.2 Dynamic',
#   '2005',
#   '196.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '223.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2014',
#   '56.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '379.900 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Touch',
#   '2019',
#   '75.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '579.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2019',
#   '31.500 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,5 lt',
#   '445.000 TL'],
#  ['Renault',
#   '1.0 SCe Joy',
#   '2022',
#   '18.000 km',
#   '999 cc',
#   '65 hp',
#   'Benzin',
#   'Düz',
#   '4,9 lt',
#   '452.000 TL'],
#  ['Renault',
#   '1.5 dCi Grandtour Extreme',
#   '2012',
#   '250.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,5 lt',
#   '287.500 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2014',
#   '173.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '410.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2012',
#   '160.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '360.000 TL'],
#  ['Renault',
#   '1.0 TCe Icon',
#   '2020',
#   '46.000 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '600.000 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2013',
#   '147.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '369.000 TL'],
#  ['Renault',
#   '1.0 SCe Joy',
#   '2021',
#   '19.500 km',
#   '999 cc',
#   '65 hp',
#   'Benzin',
#   'Düz',
#   '4,9 lt',
#   '464.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '121.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '415.000 TL'],
#  ['Renault',
#   '1.0 SCe Joy',
#   '2022',
#   '7.900 km',
#   '999 cc',
#   '65 hp',
#   'Benzin',
#   'Düz',
#   '4,9 lt',
#   '450.000 TL'],
#  ['Renault',
#   '1.4 RTA',
#   '2001',
#   '230.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,8 lt',
#   '180.000 TL'],
#  ['Renault',
#   '1.4 RTA',
#   '2000',
#   '185.000 km',
#   '1390 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '6,8 lt',
#   '195.000 TL'],
#  ['Renault',
#   '1.5 dCi GT Line',
#   '2016',
#   '148.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '404.900 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '80.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '465.000 TL'],
#  ['Renault',
#   '1.5 dCi Grandtour Extreme',
#   '2011',
#   '98.000 km',
#   '1461 cc',
#   '85 hp',
#   'Dizel',
#   'Düz',
#   '4,4 lt',
#   '333.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2015',
#   '97.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '455.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2001',
#   '242.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '186.000 TL'],
#  ['Renault',
#   '1.6 RTE',
#   '2000',
#   '233.000 km',
#   '1598 cc',
#   '90 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '182.500 TL'],
#  ['Renault',
#   '1.2 Touch',
#   '2013',
#   '66.000 km',
#   '1197 cc',
#   '120 hp',
#   'Benzin',
#   'Yarı Otomatik',
#   '5,2 lt',
#   '442.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2005',
#   '318.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '143.750 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2012',
#   '120.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '372.000 TL'],
#  ['Renault',
#   '1.2 Grandtour Extreme',
#   '2011',
#   '170.000 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '285.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2017',
#   '184.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '445.000 TL'],
#  ['Renault',
#   '0.9 TCe Sport Tourer Joy',
#   '2020',
#   '61.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '5,1 lt',
#   '407.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Touch',
#   '2014',
#   '210.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4 lt',
#   '310.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2017',
#   '214.500 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '445.000 TL'],
#  ['Renault',
#   '1.5 dCi Expression',
#   '2007',
#   '186.000 km',
#   '1461 cc',
#   '85 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '269.500 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2006',
#   '265.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '172.500 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2017',
#   '125.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '502.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2023',
#   '1.001 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '587.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '78.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '429.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2013',
#   '183.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '365.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2015',
#   '60.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '425.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2016',
#   '111.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '460.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Icon',
#   '2017',
#   '83.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '500.000 TL'],
#  ['Renault',
#   '1.5 dCi Expression',
#   '2012',
#   '99.000 km',
#   '1461 cc',
#   '68 hp',
#   'Dizel',
#   'Düz',
#   '4,5 lt',
#   '283.000 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2014',
#   '99.320 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '360.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2014',
#   '141.350 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '385.000 TL'],
#  ['Renault',
#   '1.2 Joy',
#   '2012',
#   '77.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '400.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2000',
#   '212.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '181.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2022',
#   '0 km',
#   '999 cc',
#   '100 hp',
#   'Benzin',
#   'Düz',
#   '4,3 lt',
#   '565.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2017',
#   '151.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '345.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2019',
#   '95.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '430.000 TL'],
#  ['Renault',
#   '1.4 Dynamique',
#   '2002',
#   '144.500 km',
#   '1390 cc',
#   '98 hp',
#   'Benzin',
#   'Düz',
#   '7 lt',
#   '207.000 TL'],
#  ['Renault',
#   '1.4 Alize',
#   '2006',
#   '26.500 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7 lt',
#   '225.000 TL'],
#  ['Renault',
#   '1.0 SCe Joy',
#   '2022',
#   '19.000 km',
#   nan,
#   '51 - 75 HP',
#   'Benzin',
#   'Düz',
#   nan,
#   '448.500 TL'],
#  ['Renault',
#   '1.6 RTE',
#   '2001',
#   '244.000 km',
#   '1598 cc',
#   '90 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,2 lt',
#   '163.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2019',
#   '172.500 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '425.000 TL'],
#  ['Renault',
#   '1.2 Icon',
#   '2017',
#   '27.007 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,5 lt',
#   '420.500 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2015',
#   '179.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '413.950 TL'],
#  ['Renault',
#   '0.9 TCe Icon',
#   '2013',
#   '112.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '4,5 lt',
#   '400.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2015',
#   '129.500 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '419.500 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2011',
#   '220.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,5 lt',
#   '265.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2014',
#   '115.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '415.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2015',
#   '133.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4 lt',
#   '362.500 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '111.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '424.000 TL'],
#  ['Renault',
#   '1.8 RSi',
#   '1997',
#   '225.000 km',
#   '1794 cc',
#   '109 hp',
#   'Benzin',
#   'Düz',
#   nan,
#   '150.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2017',
#   '90.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '385.000 TL'],
#  ['Renault',
#   '1.0 TCe Joy',
#   '2021',
#   '1.250 km',
#   '999 cc',
#   '100 hp',
#   'LPG & Benzin',
#   'Düz',
#   '4,3 lt',
#   '520.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2017',
#   '150.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '475.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2007',
#   '300.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,3 lt',
#   '165.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2003',
#   '214.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,3 lt',
#   '180.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2000',
#   '168.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '175.000 TL'],
#  ['Renault',
#   '1.2 Extreme',
#   '2009',
#   '120.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '290.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2016',
#   '190.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '419.900 TL'],
#  ['Renault',
#   '1.5 dCi Expression',
#   '2003',
#   '258.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '190.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2016',
#   '95.200 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '440.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Touch',
#   '2018',
#   '116.158 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '530.000 TL'],
#  ['Renault',
#   '1.5 dCi Icon',
#   '2015',
#   '137.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '415.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2016',
#   '164.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '302.750 TL'],
#  ['Renault',
#   '1.0 SCe Joy',
#   '2020',
#   '54.000 km',
#   '999 cc',
#   '72 hp',
#   'Benzin',
#   'Düz',
#   '4,9 lt',
#   '440.000 TL'],
#  ['Renault',
#   '1.0 TCe Touch',
#   '2021',
#   '27.088 km',
#   '999 cc',
#   '90 hp',
#   'Benzin',
#   'Otomatik',
#   '5 lt',
#   '557.000 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2005',
#   '314.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '177.500 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2006',
#   '160.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,9 lt',
#   '260.000 TL'],
#  ['Renault',
#   '0.9 TCe Touch',
#   '2019',
#   '87.000 km',
#   '898 cc',
#   '90 hp',
#   'Benzin',
#   'Düz',
#   '5 lt',
#   '425.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2007',
#   '237.000 km',
#   '1461 cc',
#   '80 hp',
#   'Dizel',
#   'Düz',
#   '4,8 lt',
#   '233.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2018',
#   '65.649 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '471.900 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2014',
#   '196.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '385.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '70.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '450.000 TL'],
#  ['Renault',
#   '1.4 RTA',
#   '2000',
#   '216.214 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Otomatik',
#   nan,
#   '198.750 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2008',
#   '275.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,7 lt',
#   '195.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2016',
#   '168.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4 lt',
#   '365.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2019',
#   '109.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '433.500 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2006',
#   '175.100 km',
#   '1149 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '5,9 lt',
#   '224.500 TL'],
#  ['Renault',
#   '1.2 Authentique',
#   '2005',
#   '99.000 km',
#   '1149 cc',
#   '75 hp',
#   'Benzin',
#   'Düz',
#   '5,9 lt',
#   '255.000 TL'],
#  ['Renault',
#   '1.5 dCi SportTourer Joy',
#   '2013',
#   '107.500 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '4 lt',
#   '360.000 TL'],
#  ['Renault',
#   '1.5 dCi Extreme',
#   '2011',
#   '305.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,5 lt',
#   '255.000 TL'],
#  ['Renault',
#   '1.4 Fidji',
#   '2004',
#   '308.000 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,3 lt',
#   '173.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2017',
#   '139.980 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '410.000 TL'],
#  ['Renault',
#   '1.4 RNA',
#   '2000',
#   '217.000 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '195.000 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2004',
#   '257.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '167.000 TL'],
#  ['Renault',
#   '1.6 RTE',
#   '2000',
#   '293.000 km',
#   nan,
#   nan,
#   'LPG & Benzin',
#   'Düz',
#   nan,
#   '198.500 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '76.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '439.950 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2019',
#   '93.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '449.950 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2005',
#   '217.700 km',
#   '1390 cc',
#   '75 hp',
#   'LPG & Benzin',
#   'Düz',
#   '7,1 lt',
#   '223.500 TL'],
#  ['Renault',
#   '1.5 dCi Alize',
#   '2006',
#   '183.500 km',
#   '1461 cc',
#   '80 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '236.000 TL'],
#  ['Renault',
#   '1.5 dCi Authentique',
#   '2004',
#   '285.000 km',
#   '1461 cc',
#   '65 hp',
#   'Dizel',
#   'Düz',
#   '4,7 lt',
#   '186.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2018',
#   '99.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '439.950 TL'],
#  ['Renault',
#   '1.4 Authentique',
#   '2005',
#   '155.500 km',
#   '1390 cc',
#   '98 hp',
#   'LPG & Benzin',
#   'Düz',
#   '6,6 lt',
#   '251.000 TL'],
#  ['Renault',
#   '1.5 dCi Joy',
#   '2016',
#   '140.000 km',
#   '1461 cc',
#   '75 hp',
#   'Dizel',
#   'Düz',
#   '3,6 lt',
#   '350.000 TL'],
#  ['Renault',
#   '1.5 dCi Touch',
#   '2017',
#   '96.000 km',
#   '1461 cc',
#   '90 hp',
#   'Dizel',
#   'Yarı Otomatik',
#   '3,7 lt',
#   '520.000 TL'],
#  ...]

# %%
len(features)
# Out:
# 2500

# %%
model
# Out:
# '1.5 dCi SportTourer Touch'

# %%
df_columns = ["Brand","Model","Year","Km","EngSize","Hp","Fuel","Gear Type",
             "Fuel Consumption ","Price"]

df = pd.DataFrame.from_records(features, columns=df_columns)

# %%
df.head()
# Out:
#      Brand            Model  Year          Km  EngSize     Hp    Fuel  \
# 0  Renault    1.5 dCi Touch  2018  110.000 km  1461 cc  90 hp   Dizel
# 1  Renault  1.2 Authentique  2004  133.500 km  1149 cc  75 hp  Benzin
# 2  Renault      1.0 TCe Joy  2022    7.524 km   999 cc  90 hp  Benzin
# 3  Renault      1.5 dCi Joy  2016  148.000 km  1461 cc  75 hp   Dizel
# 4  Renault    1.5 dCi Touch  2018  112.000 km  1461 cc  90 hp   Dizel
#
#        Gear Type Fuel Consumption        Price
# 0  Yarı Otomatik            3,7 lt  525.000 TL
# 1            Düz            5,9 lt  227.000 TL
# 2       Otomatik              5 lt  665.000 TL
# 3            Düz            3,6 lt  335.000 TL
# 4  Yarı Otomatik            3,7 lt  472.500 TL

# %%
df.to_csv("firstdf.csv")
